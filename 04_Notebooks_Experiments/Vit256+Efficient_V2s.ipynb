# %%
# !pip install timm transformers datasets accelerate --quiet

# %%
# !pip install shap --quiet

# %% [markdown]
# ### What is SHAP?
#
# SHAP (SHapley Additive exPlanations) is a game-theoretic approach to explain the output of any machine learning model. It connects optimal credit allocation with local explanations using the classic Shapley values from game theory.
#
# For an image classification model, SHAP can tell us which parts (pixels or superpixels) of an input image contributed most positively or negatively to a specific class prediction. This helps in understanding the model's decision-making process, identifying potential biases, and building trust in the model.
#
# To apply SHAP to our hybrid model, we'll need to:
# 1.  **Define a prediction function**: This function will take raw images as input, pass them through the `HybridFeatureExtractor`, and then use the trained XGBoost model to get class probabilities.
# 2.  **Select background data**: SHAP's `KernelExplainer` needs a representative background dataset to understand the typical feature values and compute baselines.
# 3.  **Select samples for explanation**: We'll pick a few images from the test set to visualize their SHAP explanations.

# %%
import zipfile
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_path="/content/drive/MyDrive/Research_project/TrashNeXt Dataset.zip"
extract_path = "/content"

# %%
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted to:", extract_path)
# !ls {extract_path}
# Out:
# Dataset extracted to: /content
#  drive	 __MACOSX   sample_data  'TrashNeXt Dataset'

# %%
import os
from PIL import Image
from tqdm import tqdm

def is_corrupted_image(file_path):
    """Check if an image file is corrupted."""
    try:
        with Image.open(file_path) as img:
            img.verify()  # Verify integrity
        return False
    except (IOError, SyntaxError, Image.DecompressionBombError):
        return True

def remove_corrupted_images(dataset_path):
    """Scan and remove corrupted images + hidden macOS files."""
    corrupted_count = 0
    total_images = 0

    for root, _, files in os.walk(dataset_path):
        for file in tqdm(files, desc=f"Scanning {os.path.basename(root)}"):

            # Skip hidden files (.DS_Store, ._files)
            if file.startswith("."):
                file_path = os.path.join(root, file)
                try:
                    os.remove(file_path)
                    corrupted_count += 1
                    print(f"Removed hidden file: {file_path}")
                except:
                    pass
                continue

            # Check only image formats
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
                total_images += 1
                file_path = os.path.join(root, file)
                if is_corrupted_image(file_path):
                    try:
                        os.remove(file_path)
                        corrupted_count += 1
                        print(f"Removed corrupted image: {file_path}")
                    except Exception as e:
                        print(f"Error removing {file_path}: {e}")

    print("\n✅ Scan completed!")
    print(f"📷 Total images scanned: {total_images}")
    print(f"🗑️ Corrupted/hidden files removed: {corrupted_count}")

# Run the cleaner
dataset_path = '/content/dataset'  # Your dataset path
remove_corrupted_images(dataset_path)
# Out:
# Scanning dataset: 100%|██████████| 1/1 [00:00<00:00, 2916.76it/s]
# Removed hidden file: /content/dataset/.DS_Store
# Scanning Train: 100%|██████████| 1/1 [00:00<00:00, 7345.54it/s]
# Removed hidden file: /content/dataset/Train/.DS_Store
# Scanning metal: 100%|██████████| 2065/2065 [00:03<00:00, 634.16it/s]
# Scanning cardboard: 100%|██████████| 1886/1886 [00:02<00:00, 785.88it/s]
# Scanning glass: 100%|██████████| 2009/2009 [00:00<00:00, 10016.16it/s]
# Scanning e-waste: 100%|██████████| 2404/2404 [00:00<00:00, 3196.58it/s]
# Scanning medical: 100%|██████████| 1565/1565 [00:00<00:00, 9013.53it/s]
# Scanning foam_rubber: 100%|██████████| 2289/2289 [00:00<00:00, 9828.30it/s]
# Scanning paper: 100%|██████████| 2155/2155 [00:02<00:00, 924.93it/s]
# Scanning organic: 100%|██████████| 2391/2391 [00:01<00:00, 1533.34it/s]
# Scanning plastic: 100%|██████████| 2135/2135 [00:00<00:00, 7570.09it/s]
# Scanning Test: 100%|██████████| 1/1 [00:00<00:00, 5159.05it/s]
# Removed hidden file: /content/dataset/Test/.DS_Store
# Scanning metal: 100%|██████████| 258/258 [00:00<00:00, 818.45it/s]
# Scanning cardboard: 100%|██████████| 235/235 [00:00<00:00, 843.55it/s]
# Scanning glass: 100%|██████████| 252/252 [00:00<00:00, 782.66it/s]
# Scanning e-waste: 100%|██████████| 301/301 [00:00<00:00, 820.99it/s]
# Scanning medical: 100%|██████████| 196/196 [00:00<00:00, 708.82it/s]
# Scanning foam_rubber: 100%|██████████| 287/287 [00:00<00:00, 750.53it/s]
# Scanning paper: 100%|██████████| 270/270 [00:00<00:00, 946.35it/s]
# Scanning organic: 100%|██████████| 299/299 [00:00<00:00, 1647.17it/s]
# Scanning plastic: 100%|██████████| 267/267 [00:00<00:00, 771.54it/s]
# Scanning Valid: 100%|██████████| 1/1 [00:00<00:00, 4202.71it/s]
# Removed hidden file: /content/dataset/Valid/.DS_Store
# Scanning metal: 100%|██████████| 258/258 [00:00<00:00, 869.32it/s]
# Scanning cardboard: 100%|██████████| 236/236 [00:00<00:00, 806.80it/s]
# Scanning glass: 100%|██████████| 251/251 [00:00<00:00, 883.45it/s]
# Scanning e-waste: 100%|██████████| 301/301 [00:00<00:00, 717.82it/s]
# Scanning medical: 100%|██████████| 196/196 [00:00<00:00, 697.34it/s]
# Scanning foam_rubber: 100%|██████████| 287/287 [00:00<00:00, 705.21it/s]
# Scanning paper: 100%|██████████| 269/269 [00:00<00:00, 882.85it/s]
# Scanning organic: 100%|██████████| 299/299 [00:00<00:00, 1595.93it/s]
# Scanning plastic: 100%|██████████| 267/267 [00:00<00:00, 756.26it/s]
# ✅ Scan completed!
# 📷 Total images scanned: 23625
# 🗑️ Corrupted/hidden files removed: 4

# %%
from PIL import Image
import os

def remove_truncated_images(dataset_path):
    for root, _, files in os.walk(dataset_path):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                try:
                    img_path = os.path.join(root, file)
                    img = Image.open(img_path)
                    img.verify()
                except Exception as e:
                    print(f"Removing corrupted/truncated: {img_path}")
                    os.remove(img_path)

remove_truncated_images("/content/dataset")

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
import torch
import torch.nn as nn
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import timm
import numpy as np
import os
from tqdm import tqdm

# %%
class HybridFeatureExtractor(nn.Module):
    def __init__(self):
        super(HybridFeatureExtractor, self).__init__()
        # EfficientNetV2 feature extractor
        self.efficientnet = models.efficientnet_v2_s(weights="IMAGENET1K_V1")
        self.efficientnet.classifier = nn.Identity()

        # LeViT feature extractor
        self.levit = timm.create_model('levit_256', pretrained=True)

        # Replace classification heads with identity
        self.levit.head = nn.Identity()
        if hasattr(self.levit, 'dist_head'):
            self.levit.dist_head = nn.Identity()

        # ✅ Force LeViT to skip forward_head completely
        def forward_override(x):
            # run backbone (patch embedding + transformer encoder + pooling)
            x = self.levit.forward_features(x)   # [B, N, D]
            # take CLS token only (LeViT uses CLS for classification)
            x = x[:, 0, :]                       # [B, D]
            return x
        self.levit.forward = forward_override

    def forward(self, x):
        # Resize for each model
        x_eff = transforms.functional.resize(x, (300, 300))
        x_levit = transforms.functional.resize(x, (224, 224))

        with torch.no_grad():
            features_eff = self.efficientnet(x_eff)  # [B, 1280]
            features_levit = self.levit(x_levit)     # [B, 512]

        return torch.cat((features_eff, features_levit), dim=1)

# %%
def extract_features(data_loader, model, device):
    all_features = []
    all_labels = []

    model.eval()
    for images, labels in tqdm(data_loader, desc="Extracting features"):
        images = images.to(device)
        features = model(images)
        all_features.append(features.cpu().numpy())
        all_labels.append(labels.cpu().numpy())

    return np.concatenate(all_features), np.concatenate(all_labels)

# %%
if __name__ == '__main__':
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # --- Data Loading ---
    # ❗️ IMPORTANT: Update these paths to your dataset location in Google Drive
    train_dir = "/content/dataset/Train" # Corrected path
    valid_dir = "/content/dataset/Valid" # Corrected path

    data_transforms = transforms.Compose([
        transforms.Resize((256, 256)), # Initial resize
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

    train_dataset = datasets.ImageFolder(train_dir, transform=data_transforms)
    valid_dataset = datasets.ImageFolder(valid_dir, transform=data_transforms)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
    valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)

    # --- Initialize model and extract ---
    feature_extractor = HybridFeatureExtractor().to(device)

    X_train, y_train = extract_features(train_loader, feature_extractor, device)
    X_valid, y_valid = extract_features(valid_loader, feature_extractor, device)

    print(f"Training features shape: {X_train.shape}")
    print(f"Validation features shape: {X_valid.shape}")

    # Save features for the next stage
    np.save('X_train.npy', X_train)
    np.save('y_train.npy', y_train)
    np.save('X_valid.npy', X_valid)
    np.save('y_valid.npy', y_valid)
    print("✅ Features saved!")
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_s-dd5fe13b.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2_s-dd5fe13b.pth
# 100%|██████████| 82.7M/82.7M [00:00<00:00, 175MB/s]
# model.safetensors:   0%|          | 0.00/75.9M [00:00<?, ?B/s]
# Extracting features:   0%|          | 0/591 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Extracting features: 100%|██████████| 591/591 [06:43<00:00,  1.47it/s]
# Extracting features: 100%|██████████| 74/74 [00:50<00:00,  1.47it/s]
# Training features shape: (18898, 1792)
# Validation features shape: (2363, 1792)
# ✅ Features saved!

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import accuracy_score, log_loss
import matplotlib.pyplot as plt

# --- Load extracted features ---
X_train = np.load("X_train.npy")
y_train = np.load("y_train.npy")
X_valid = np.load("X_valid.npy")
y_valid = np.load("y_valid.npy")

# %%
# Create DMatrix (optimized format for XGBoost)
dtrain = xgb.DMatrix(X_train, label=y_train)
dvalid = xgb.DMatrix(X_valid, label=y_valid)

# --- XGBoost Parameters ---
params = {
    'objective': 'multi:softprob',   # multi-class classification
    'num_class': len(np.unique(y_train)),
    'eval_metric': 'mlogloss',
    'learning_rate': 0.25858285509781914,
    'max_depth': 5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'seed': 42
}

# %%
# --- Training with evaluation ---
num_rounds = 236   # total boosting rounds (like epochs)
evals = [(dtrain, 'train'), (dvalid, 'valid')]
evals_result = {}

model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_rounds,
    evals=evals,
    evals_result=evals_result,
    verbose_eval=1
)

# --- Collect metrics ---
train_logloss = evals_result['train']['mlogloss']
valid_logloss = evals_result['valid']['mlogloss']

# Accuracy at each round
train_acc, valid_acc = [], []
for i in range(1, num_rounds+1):
    y_train_pred = np.argmax(model.predict(dtrain, iteration_range=(0, i)), axis=1)
    y_valid_pred = np.argmax(model.predict(dvalid, iteration_range=(0, i)), axis=1)
    train_acc.append(accuracy_score(y_train, y_train_pred))
    valid_acc.append(accuracy_score(y_valid, y_valid_pred))

    print(f"Round {i}/{num_rounds} "
          f"| Train Loss: {train_logloss[i-1]:.4f}, Train Acc: {train_acc[-1]:.4f} "
          f"| Val Loss: {valid_logloss[i-1]:.4f}, Val Acc: {valid_acc[-1]:.4f}")
# Out:
# [0]	train-mlogloss:1.58934	valid-mlogloss:1.63234
# [1]	train-mlogloss:1.29788	valid-mlogloss:1.37084
# [2]	train-mlogloss:1.09503	valid-mlogloss:1.18360
# [3]	train-mlogloss:0.94657	valid-mlogloss:1.05146
# [4]	train-mlogloss:0.82815	valid-mlogloss:0.94280
# [5]	train-mlogloss:0.73492	valid-mlogloss:0.85927
# [6]	train-mlogloss:0.65580	valid-mlogloss:0.78898
# [7]	train-mlogloss:0.59125	valid-mlogloss:0.73142
# [8]	train-mlogloss:0.53650	valid-mlogloss:0.68482
# [9]	train-mlogloss:0.48890	valid-mlogloss:0.64544
# [10]	train-mlogloss:0.44791	valid-mlogloss:0.61040
# [11]	train-mlogloss:0.41139	valid-mlogloss:0.57980
# [12]	train-mlogloss:0.37887	valid-mlogloss:0.55487
# [13]	train-mlogloss:0.35052	valid-mlogloss:0.53394
# [14]	train-mlogloss:0.32549	valid-mlogloss:0.51630
# [15]	train-mlogloss:0.30296	valid-mlogloss:0.49814
# [16]	train-mlogloss:0.28268	valid-mlogloss:0.48205
# [17]	train-mlogloss:0.26456	valid-mlogloss:0.46863
# [18]	train-mlogloss:0.24756	valid-mlogloss:0.45700
# [19]	train-mlogloss:0.23165	valid-mlogloss:0.44674
# [20]	train-mlogloss:0.21766	valid-mlogloss:0.43810
# [21]	train-mlogloss:0.20454	valid-mlogloss:0.42870
# [22]	train-mlogloss:0.19221	valid-mlogloss:0.42019
# [23]	train-mlogloss:0.18045	valid-mlogloss:0.41368
# [24]	train-mlogloss:0.17004	valid-mlogloss:0.40839
# [25]	train-mlogloss:0.16026	valid-mlogloss:0.40209
# [26]	train-mlogloss:0.15104	valid-mlogloss:0.39556
# [27]	train-mlogloss:0.14254	valid-mlogloss:0.39046
# [28]	train-mlogloss:0.13517	valid-mlogloss:0.38623
# [29]	train-mlogloss:0.12838	valid-mlogloss:0.38251
# [30]	train-mlogloss:0.12107	valid-mlogloss:0.37999
# [31]	train-mlogloss:0.11412	valid-mlogloss:0.37571
# [32]	train-mlogloss:0.10811	valid-mlogloss:0.37159
# [33]	train-mlogloss:0.10247	valid-mlogloss:0.36920
# [34]	train-mlogloss:0.09736	valid-mlogloss:0.36539
# [35]	train-mlogloss:0.09285	valid-mlogloss:0.36166
# [36]	train-mlogloss:0.08798	valid-mlogloss:0.35867
# [37]	train-mlogloss:0.08306	valid-mlogloss:0.35590
# [38]	train-mlogloss:0.07872	valid-mlogloss:0.35290
# [39]	train-mlogloss:0.07489	valid-mlogloss:0.35017
# [40]	train-mlogloss:0.07150	valid-mlogloss:0.34804
# [41]	train-mlogloss:0.06782	valid-mlogloss:0.34670
# [42]	train-mlogloss:0.06452	valid-mlogloss:0.34386
# [43]	train-mlogloss:0.06149	valid-mlogloss:0.34278
# [44]	train-mlogloss:0.05896	valid-mlogloss:0.34132
# [45]	train-mlogloss:0.05610	valid-mlogloss:0.33997
# [46]	train-mlogloss:0.05367	valid-mlogloss:0.33688
# [47]	train-mlogloss:0.05123	valid-mlogloss:0.33539
# [48]	train-mlogloss:0.04873	valid-mlogloss:0.33329
# [49]	train-mlogloss:0.04637	valid-mlogloss:0.33209
# [50]	train-mlogloss:0.04413	valid-mlogloss:0.33001
# [51]	train-mlogloss:0.04197	valid-mlogloss:0.32901
# [52]	train-mlogloss:0.04014	valid-mlogloss:0.32784
# [53]	train-mlogloss:0.03845	valid-mlogloss:0.32753
# [54]	train-mlogloss:0.03671	valid-mlogloss:0.32633
# [55]	train-mlogloss:0.03519	valid-mlogloss:0.32569
# [56]	train-mlogloss:0.03375	valid-mlogloss:0.32456
# [57]	train-mlogloss:0.03228	valid-mlogloss:0.32351
# [58]	train-mlogloss:0.03100	valid-mlogloss:0.32262
# [59]	train-mlogloss:0.02968	valid-mlogloss:0.32148
# [60]	train-mlogloss:0.02849	valid-mlogloss:0.32014
# [61]	train-mlogloss:0.02720	valid-mlogloss:0.31877
# [62]	train-mlogloss:0.02610	valid-mlogloss:0.31777
# [63]	train-mlogloss:0.02516	valid-mlogloss:0.31754
# [64]	train-mlogloss:0.02413	valid-mlogloss:0.31636
# [65]	train-mlogloss:0.02315	valid-mlogloss:0.31550
# [66]	train-mlogloss:0.02217	valid-mlogloss:0.31427
# [67]	train-mlogloss:0.02129	valid-mlogloss:0.31309
# [68]	train-mlogloss:0.02046	valid-mlogloss:0.31285
# [69]	train-mlogloss:0.01967	valid-mlogloss:0.31213
# [70]	train-mlogloss:0.01902	valid-mlogloss:0.31157
# [71]	train-mlogloss:0.01825	valid-mlogloss:0.31133
# [72]	train-mlogloss:0.01761	valid-mlogloss:0.31077
# [73]	train-mlogloss:0.01695	valid-mlogloss:0.31044
# [74]	train-mlogloss:0.01631	valid-mlogloss:0.31022
# [75]	train-mlogloss:0.01568	valid-mlogloss:0.31026
# [76]	train-mlogloss:0.01510	valid-mlogloss:0.30889
# [77]	train-mlogloss:0.01455	valid-mlogloss:0.30838
# [78]	train-mlogloss:0.01404	valid-mlogloss:0.30819
# [79]	train-mlogloss:0.01357	valid-mlogloss:0.30781
# [80]	train-mlogloss:0.01310	valid-mlogloss:0.30754
# [81]	train-mlogloss:0.01271	valid-mlogloss:0.30781
# [82]	train-mlogloss:0.01227	valid-mlogloss:0.30770
# [83]	train-mlogloss:0.01189	valid-mlogloss:0.30746
# [84]	train-mlogloss:0.01148	valid-mlogloss:0.30750
# [85]	train-mlogloss:0.01109	valid-mlogloss:0.30765
# [86]	train-mlogloss:0.01074	valid-mlogloss:0.30678
# [87]	train-mlogloss:0.01042	valid-mlogloss:0.30669
# [88]	train-mlogloss:0.01008	valid-mlogloss:0.30590
# [89]	train-mlogloss:0.00976	valid-mlogloss:0.30502
# [90]	train-mlogloss:0.00946	valid-mlogloss:0.30504
# [91]	train-mlogloss:0.00919	valid-mlogloss:0.30524
# [92]	train-mlogloss:0.00891	valid-mlogloss:0.30540
# [93]	train-mlogloss:0.00862	valid-mlogloss:0.30591
# [94]	train-mlogloss:0.00837	valid-mlogloss:0.30553
# [95]	train-mlogloss:0.00812	valid-mlogloss:0.30561
# [96]	train-mlogloss:0.00787	valid-mlogloss:0.30599
# [97]	train-mlogloss:0.00767	valid-mlogloss:0.30601
# [98]	train-mlogloss:0.00747	valid-mlogloss:0.30630
# [99]	train-mlogloss:0.00725	valid-mlogloss:0.30630
# [100]	train-mlogloss:0.00705	valid-mlogloss:0.30589
# [101]	train-mlogloss:0.00687	valid-mlogloss:0.30612
# [102]	train-mlogloss:0.00669	valid-mlogloss:0.30561
# [103]	train-mlogloss:0.00650	valid-mlogloss:0.30582
# [104]	train-mlogloss:0.00634	valid-mlogloss:0.30539
# [105]	train-mlogloss:0.00618	valid-mlogloss:0.30528
# [106]	train-mlogloss:0.00604	valid-mlogloss:0.30559
# [107]	train-mlogloss:0.00590	valid-mlogloss:0.30604
# [108]	train-mlogloss:0.00576	valid-mlogloss:0.30540
# [109]	train-mlogloss:0.00562	valid-mlogloss:0.30539
# [110]	train-mlogloss:0.00548	valid-mlogloss:0.30560
# [111]	train-mlogloss:0.00536	valid-mlogloss:0.30507
# [112]	train-mlogloss:0.00523	valid-mlogloss:0.30483
# [113]	train-mlogloss:0.00511	valid-mlogloss:0.30483
# [114]	train-mlogloss:0.00500	valid-mlogloss:0.30465
# [115]	train-mlogloss:0.00490	valid-mlogloss:0.30438
# [116]	train-mlogloss:0.00480	valid-mlogloss:0.30465
# [117]	train-mlogloss:0.00471	valid-mlogloss:0.30452
# [118]	train-mlogloss:0.00461	valid-mlogloss:0.30456
# [119]	train-mlogloss:0.00452	valid-mlogloss:0.30452
# [120]	train-mlogloss:0.00442	valid-mlogloss:0.30441
# [121]	train-mlogloss:0.00432	valid-mlogloss:0.30498
# [122]	train-mlogloss:0.00424	valid-mlogloss:0.30492
# [123]	train-mlogloss:0.00415	valid-mlogloss:0.30527
# [124]	train-mlogloss:0.00407	valid-mlogloss:0.30507
# [125]	train-mlogloss:0.00399	valid-mlogloss:0.30554
# [126]	train-mlogloss:0.00392	valid-mlogloss:0.30518
# [127]	train-mlogloss:0.00385	valid-mlogloss:0.30564
# [128]	train-mlogloss:0.00377	valid-mlogloss:0.30576
# [129]	train-mlogloss:0.00370	valid-mlogloss:0.30617
# [130]	train-mlogloss:0.00364	valid-mlogloss:0.30610
# [131]	train-mlogloss:0.00358	valid-mlogloss:0.30625
# [132]	train-mlogloss:0.00352	valid-mlogloss:0.30613
# [133]	train-mlogloss:0.00346	valid-mlogloss:0.30540
# [134]	train-mlogloss:0.00341	valid-mlogloss:0.30553
# [135]	train-mlogloss:0.00335	valid-mlogloss:0.30600
# [136]	train-mlogloss:0.00330	valid-mlogloss:0.30637
# [137]	train-mlogloss:0.00324	valid-mlogloss:0.30643
# [138]	train-mlogloss:0.00318	valid-mlogloss:0.30650
# [139]	train-mlogloss:0.00314	valid-mlogloss:0.30674
# [140]	train-mlogloss:0.00309	valid-mlogloss:0.30644
# [141]	train-mlogloss:0.00304	valid-mlogloss:0.30628
# [142]	train-mlogloss:0.00299	valid-mlogloss:0.30724
# [143]	train-mlogloss:0.00295	valid-mlogloss:0.30714
# [144]	train-mlogloss:0.00291	valid-mlogloss:0.30724
# [145]	train-mlogloss:0.00287	valid-mlogloss:0.30695
# [146]	train-mlogloss:0.00283	valid-mlogloss:0.30687
# [147]	train-mlogloss:0.00279	valid-mlogloss:0.30684
# [148]	train-mlogloss:0.00275	valid-mlogloss:0.30671
# [149]	train-mlogloss:0.00271	valid-mlogloss:0.30677
# [150]	train-mlogloss:0.00268	valid-mlogloss:0.30665
# [151]	train-mlogloss:0.00264	valid-mlogloss:0.30660
# [152]	train-mlogloss:0.00260	valid-mlogloss:0.30647
# [153]	train-mlogloss:0.00257	valid-mlogloss:0.30662
# [154]	train-mlogloss:0.00254	valid-mlogloss:0.30652
# [155]	train-mlogloss:0.00250	valid-mlogloss:0.30618
# [156]	train-mlogloss:0.00247	valid-mlogloss:0.30618
# [157]	train-mlogloss:0.00244	valid-mlogloss:0.30610
# [158]	train-mlogloss:0.00241	valid-mlogloss:0.30629
# [159]	train-mlogloss:0.00238	valid-mlogloss:0.30638
# [160]	train-mlogloss:0.00235	valid-mlogloss:0.30669
# [161]	train-mlogloss:0.00232	valid-mlogloss:0.30694
# [162]	train-mlogloss:0.00230	valid-mlogloss:0.30710
# [163]	train-mlogloss:0.00227	valid-mlogloss:0.30746
# [164]	train-mlogloss:0.00225	valid-mlogloss:0.30777
# [165]	train-mlogloss:0.00222	valid-mlogloss:0.30762
# [166]	train-mlogloss:0.00219	valid-mlogloss:0.30773
# [167]	train-mlogloss:0.00217	valid-mlogloss:0.30783
# [168]	train-mlogloss:0.00215	valid-mlogloss:0.30794
# [169]	train-mlogloss:0.00212	valid-mlogloss:0.30803
# [170]	train-mlogloss:0.00210	valid-mlogloss:0.30807
# [171]	train-mlogloss:0.00208	valid-mlogloss:0.30829
# [172]	train-mlogloss:0.00206	valid-mlogloss:0.30839
# [173]	train-mlogloss:0.00204	valid-mlogloss:0.30828
# [174]	train-mlogloss:0.00202	valid-mlogloss:0.30820
# [175]	train-mlogloss:0.00200	valid-mlogloss:0.30851
# [176]	train-mlogloss:0.00198	valid-mlogloss:0.30813
# [177]	train-mlogloss:0.00196	valid-mlogloss:0.30818
# [178]	train-mlogloss:0.00194	valid-mlogloss:0.30832
# [179]	train-mlogloss:0.00192	valid-mlogloss:0.30814
# [180]	train-mlogloss:0.00190	valid-mlogloss:0.30814
# [181]	train-mlogloss:0.00188	valid-mlogloss:0.30823
# [182]	train-mlogloss:0.00187	valid-mlogloss:0.30851
# [183]	train-mlogloss:0.00185	valid-mlogloss:0.30899
# [184]	train-mlogloss:0.00183	valid-mlogloss:0.30908
# [185]	train-mlogloss:0.00182	valid-mlogloss:0.30912
# [186]	train-mlogloss:0.00180	valid-mlogloss:0.30944
# [187]	train-mlogloss:0.00179	valid-mlogloss:0.30962
# [188]	train-mlogloss:0.00177	valid-mlogloss:0.30964
# [189]	train-mlogloss:0.00176	valid-mlogloss:0.30990
# [190]	train-mlogloss:0.00174	valid-mlogloss:0.30974
# [191]	train-mlogloss:0.00173	valid-mlogloss:0.30983
# [192]	train-mlogloss:0.00171	valid-mlogloss:0.31011
# [193]	train-mlogloss:0.00170	valid-mlogloss:0.31012
# [194]	train-mlogloss:0.00168	valid-mlogloss:0.31013
# [195]	train-mlogloss:0.00167	valid-mlogloss:0.31025
# [196]	train-mlogloss:0.00166	valid-mlogloss:0.31030
# [197]	train-mlogloss:0.00164	valid-mlogloss:0.31016
# [198]	train-mlogloss:0.00163	valid-mlogloss:0.31005
# [199]	train-mlogloss:0.00162	valid-mlogloss:0.30994
# [200]	train-mlogloss:0.00161	valid-mlogloss:0.30994
# [201]	train-mlogloss:0.00160	valid-mlogloss:0.31006
# [202]	train-mlogloss:0.00159	valid-mlogloss:0.31009
# [203]	train-mlogloss:0.00158	valid-mlogloss:0.31029
# [204]	train-mlogloss:0.00156	valid-mlogloss:0.31038
# [205]	train-mlogloss:0.00155	valid-mlogloss:0.31040
# [206]	train-mlogloss:0.00154	valid-mlogloss:0.31030
# [207]	train-mlogloss:0.00153	valid-mlogloss:0.31005
# [208]	train-mlogloss:0.00152	valid-mlogloss:0.31000
# [209]	train-mlogloss:0.00151	valid-mlogloss:0.31006
# [210]	train-mlogloss:0.00150	valid-mlogloss:0.31005
# [211]	train-mlogloss:0.00149	valid-mlogloss:0.31018
# [212]	train-mlogloss:0.00148	valid-mlogloss:0.31014
# [213]	train-mlogloss:0.00147	valid-mlogloss:0.31021
# [214]	train-mlogloss:0.00146	valid-mlogloss:0.31053
# [215]	train-mlogloss:0.00145	valid-mlogloss:0.31074
# [216]	train-mlogloss:0.00144	valid-mlogloss:0.31107
# [217]	train-mlogloss:0.00143	valid-mlogloss:0.31101
# [218]	train-mlogloss:0.00142	valid-mlogloss:0.31116
# [219]	train-mlogloss:0.00141	valid-mlogloss:0.31129
# [220]	train-mlogloss:0.00141	valid-mlogloss:0.31128
# [221]	train-mlogloss:0.00140	valid-mlogloss:0.31109
# [222]	train-mlogloss:0.00139	valid-mlogloss:0.31153
# [223]	train-mlogloss:0.00138	valid-mlogloss:0.31141
# [224]	train-mlogloss:0.00137	valid-mlogloss:0.31131
# [225]	train-mlogloss:0.00136	valid-mlogloss:0.31117
# [226]	train-mlogloss:0.00135	valid-mlogloss:0.31101
# [227]	train-mlogloss:0.00135	valid-mlogloss:0.31104
# [228]	train-mlogloss:0.00134	valid-mlogloss:0.31122
# [229]	train-mlogloss:0.00133	valid-mlogloss:0.31120
# [230]	train-mlogloss:0.00132	valid-mlogloss:0.31133
# [231]	train-mlogloss:0.00132	valid-mlogloss:0.31154
# [232]	train-mlogloss:0.00131	valid-mlogloss:0.31152
# [233]	train-mlogloss:0.00130	valid-mlogloss:0.31172
# [234]	train-mlogloss:0.00130	valid-mlogloss:0.31189
# [235]	train-mlogloss:0.00129	valid-mlogloss:0.31193
# Round 1/236 | Train Loss: 1.5893, Train Acc: 0.7628 | Val Loss: 1.6323, Val Acc: 0.7101
# Round 2/236 | Train Loss: 1.2979, Train Acc: 0.8287 | Val Loss: 1.3708, Val Acc: 0.7732
# Round 3/236 | Train Loss: 1.0950, Train Acc: 0.8579 | Val Loss: 1.1836, Val Acc: 0.7990
# Round 4/236 | Train Loss: 0.9466, Train Acc: 0.8715 | Val Loss: 1.0515, Val Acc: 0.8087
# Round 5/236 | Train Loss: 0.8281, Train Acc: 0.8832 | Val Loss: 0.9428, Val Acc: 0.8180
# Round 6/236 | Train Loss: 0.7349, Train Acc: 0.8912 | Val Loss: 0.8593, Val Acc: 0.8273
# Round 7/236 | Train Loss: 0.6558, Train Acc: 0.8992 | Val Loss: 0.7890, Val Acc: 0.8358
# Round 8/236 | Train Loss: 0.5912, Train Acc: 0.9070 | Val Loss: 0.7314, Val Acc: 0.8388
# Round 9/236 | Train Loss: 0.5365, Train Acc: 0.9134 | Val Loss: 0.6848, Val Acc: 0.8413
# Round 10/236 | Train Loss: 0.4889, Train Acc: 0.9198 | Val Loss: 0.6454, Val Acc: 0.8438
# Round 11/236 | Train Loss: 0.4479, Train Acc: 0.9245 | Val Loss: 0.6104, Val Acc: 0.8468
# Round 12/236 | Train Loss: 0.4114, Train Acc: 0.9298 | Val Loss: 0.5798, Val Acc: 0.8493
# Round 13/236 | Train Loss: 0.3789, Train Acc: 0.9348 | Val Loss: 0.5549, Val Acc: 0.8498
# Round 14/236 | Train Loss: 0.3505, Train Acc: 0.9390 | Val Loss: 0.5339, Val Acc: 0.8553
# Round 15/236 | Train Loss: 0.3255, Train Acc: 0.9439 | Val Loss: 0.5163, Val Acc: 0.8561
# Round 16/236 | Train Loss: 0.3030, Train Acc: 0.9480 | Val Loss: 0.4981, Val Acc: 0.8587
# Round 17/236 | Train Loss: 0.2827, Train Acc: 0.9527 | Val Loss: 0.4820, Val Acc: 0.8642
# Round 18/236 | Train Loss: 0.2646, Train Acc: 0.9556 | Val Loss: 0.4686, Val Acc: 0.8658
# Round 19/236 | Train Loss: 0.2476, Train Acc: 0.9592 | Val Loss: 0.4570, Val Acc: 0.8680
# Round 20/236 | Train Loss: 0.2316, Train Acc: 0.9622 | Val Loss: 0.4467, Val Acc: 0.8701
# Round 21/236 | Train Loss: 0.2177, Train Acc: 0.9661 | Val Loss: 0.4381, Val Acc: 0.8730
# Round 22/236 | Train Loss: 0.2045, Train Acc: 0.9683 | Val Loss: 0.4287, Val Acc: 0.8718
# Round 23/236 | Train Loss: 0.1922, Train Acc: 0.9711 | Val Loss: 0.4202, Val Acc: 0.8743
# Round 24/236 | Train Loss: 0.1804, Train Acc: 0.9741 | Val Loss: 0.4137, Val Acc: 0.8773
# Round 25/236 | Train Loss: 0.1700, Train Acc: 0.9765 | Val Loss: 0.4084, Val Acc: 0.8781
# Round 26/236 | Train Loss: 0.1603, Train Acc: 0.9788 | Val Loss: 0.4021, Val Acc: 0.8777
# Round 27/236 | Train Loss: 0.1510, Train Acc: 0.9806 | Val Loss: 0.3956, Val Acc: 0.8790
# Round 28/236 | Train Loss: 0.1425, Train Acc: 0.9825 | Val Loss: 0.3905, Val Acc: 0.8798
# Round 29/236 | Train Loss: 0.1352, Train Acc: 0.9843 | Val Loss: 0.3862, Val Acc: 0.8828
# Round 30/236 | Train Loss: 0.1284, Train Acc: 0.9861 | Val Loss: 0.3825, Val Acc: 0.8832
# Round 31/236 | Train Loss: 0.1211, Train Acc: 0.9875 | Val Loss: 0.3800, Val Acc: 0.8836
# Round 32/236 | Train Loss: 0.1141, Train Acc: 0.9893 | Val Loss: 0.3757, Val Acc: 0.8849
# Round 33/236 | Train Loss: 0.1081, Train Acc: 0.9907 | Val Loss: 0.3716, Val Acc: 0.8853
# Round 34/236 | Train Loss: 0.1025, Train Acc: 0.9915 | Val Loss: 0.3692, Val Acc: 0.8840
# Round 35/236 | Train Loss: 0.0974, Train Acc: 0.9924 | Val Loss: 0.3654, Val Acc: 0.8866
# Round 36/236 | Train Loss: 0.0928, Train Acc: 0.9933 | Val Loss: 0.3617, Val Acc: 0.8849
# Round 37/236 | Train Loss: 0.0880, Train Acc: 0.9939 | Val Loss: 0.3587, Val Acc: 0.8840
# Round 38/236 | Train Loss: 0.0831, Train Acc: 0.9943 | Val Loss: 0.3559, Val Acc: 0.8870
# Round 39/236 | Train Loss: 0.0787, Train Acc: 0.9948 | Val Loss: 0.3529, Val Acc: 0.8900
# Round 40/236 | Train Loss: 0.0749, Train Acc: 0.9951 | Val Loss: 0.3502, Val Acc: 0.8874
# Round 41/236 | Train Loss: 0.0715, Train Acc: 0.9955 | Val Loss: 0.3480, Val Acc: 0.8891
# Round 42/236 | Train Loss: 0.0678, Train Acc: 0.9964 | Val Loss: 0.3467, Val Acc: 0.8891
# Round 43/236 | Train Loss: 0.0645, Train Acc: 0.9967 | Val Loss: 0.3439, Val Acc: 0.8904
# Round 44/236 | Train Loss: 0.0615, Train Acc: 0.9973 | Val Loss: 0.3428, Val Acc: 0.8891
# Round 45/236 | Train Loss: 0.0590, Train Acc: 0.9974 | Val Loss: 0.3413, Val Acc: 0.8891
# Round 46/236 | Train Loss: 0.0561, Train Acc: 0.9975 | Val Loss: 0.3400, Val Acc: 0.8891
# Round 47/236 | Train Loss: 0.0537, Train Acc: 0.9980 | Val Loss: 0.3369, Val Acc: 0.8891
# Round 48/236 | Train Loss: 0.0512, Train Acc: 0.9985 | Val Loss: 0.3354, Val Acc: 0.8883
# Round 49/236 | Train Loss: 0.0487, Train Acc: 0.9987 | Val Loss: 0.3333, Val Acc: 0.8891
# Round 50/236 | Train Loss: 0.0464, Train Acc: 0.9989 | Val Loss: 0.3321, Val Acc: 0.8912
# Round 51/236 | Train Loss: 0.0441, Train Acc: 0.9992 | Val Loss: 0.3300, Val Acc: 0.8895
# Round 52/236 | Train Loss: 0.0420, Train Acc: 0.9995 | Val Loss: 0.3290, Val Acc: 0.8929
# Round 53/236 | Train Loss: 0.0401, Train Acc: 0.9995 | Val Loss: 0.3278, Val Acc: 0.8925
# Round 54/236 | Train Loss: 0.0384, Train Acc: 0.9995 | Val Loss: 0.3275, Val Acc: 0.8934
# Round 55/236 | Train Loss: 0.0367, Train Acc: 0.9995 | Val Loss: 0.3263, Val Acc: 0.8950
# Round 56/236 | Train Loss: 0.0352, Train Acc: 0.9996 | Val Loss: 0.3257, Val Acc: 0.8955
# Round 57/236 | Train Loss: 0.0337, Train Acc: 0.9996 | Val Loss: 0.3246, Val Acc: 0.8950
# Round 58/236 | Train Loss: 0.0323, Train Acc: 0.9996 | Val Loss: 0.3235, Val Acc: 0.8942
# Round 59/236 | Train Loss: 0.0310, Train Acc: 0.9998 | Val Loss: 0.3226, Val Acc: 0.8929
# Round 60/236 | Train Loss: 0.0297, Train Acc: 0.9998 | Val Loss: 0.3215, Val Acc: 0.8955
# Round 61/236 | Train Loss: 0.0285, Train Acc: 0.9998 | Val Loss: 0.3201, Val Acc: 0.8946
# Round 62/236 | Train Loss: 0.0272, Train Acc: 0.9998 | Val Loss: 0.3188, Val Acc: 0.8955
# Round 63/236 | Train Loss: 0.0261, Train Acc: 0.9998 | Val Loss: 0.3178, Val Acc: 0.8955
# Round 64/236 | Train Loss: 0.0252, Train Acc: 0.9998 | Val Loss: 0.3175, Val Acc: 0.8950
# Round 65/236 | Train Loss: 0.0241, Train Acc: 0.9999 | Val Loss: 0.3164, Val Acc: 0.8959
# Round 66/236 | Train Loss: 0.0231, Train Acc: 0.9999 | Val Loss: 0.3155, Val Acc: 0.8955
# Round 67/236 | Train Loss: 0.0222, Train Acc: 0.9999 | Val Loss: 0.3143, Val Acc: 0.8959
# Round 68/236 | Train Loss: 0.0213, Train Acc: 0.9999 | Val Loss: 0.3131, Val Acc: 0.8967
# Round 69/236 | Train Loss: 0.0205, Train Acc: 0.9999 | Val Loss: 0.3129, Val Acc: 0.8984
# Round 70/236 | Train Loss: 0.0197, Train Acc: 0.9999 | Val Loss: 0.3121, Val Acc: 0.8980
# Round 71/236 | Train Loss: 0.0190, Train Acc: 0.9999 | Val Loss: 0.3116, Val Acc: 0.8984
# Round 72/236 | Train Loss: 0.0182, Train Acc: 0.9999 | Val Loss: 0.3113, Val Acc: 0.8993
# Round 73/236 | Train Loss: 0.0176, Train Acc: 0.9999 | Val Loss: 0.3108, Val Acc: 0.8993
# Round 74/236 | Train Loss: 0.0170, Train Acc: 0.9999 | Val Loss: 0.3104, Val Acc: 0.9001
# Round 75/236 | Train Loss: 0.0163, Train Acc: 0.9999 | Val Loss: 0.3102, Val Acc: 0.9010
# Round 76/236 | Train Loss: 0.0157, Train Acc: 0.9999 | Val Loss: 0.3103, Val Acc: 0.9014
# Round 77/236 | Train Loss: 0.0151, Train Acc: 0.9999 | Val Loss: 0.3089, Val Acc: 0.9006
# Round 78/236 | Train Loss: 0.0145, Train Acc: 0.9999 | Val Loss: 0.3084, Val Acc: 0.9006
# Round 79/236 | Train Loss: 0.0140, Train Acc: 0.9999 | Val Loss: 0.3082, Val Acc: 0.8989
# Round 80/236 | Train Loss: 0.0136, Train Acc: 0.9999 | Val Loss: 0.3078, Val Acc: 0.9006
# Round 81/236 | Train Loss: 0.0131, Train Acc: 0.9999 | Val Loss: 0.3075, Val Acc: 0.8997
# Round 82/236 | Train Loss: 0.0127, Train Acc: 0.9999 | Val Loss: 0.3078, Val Acc: 0.8984
# Round 83/236 | Train Loss: 0.0123, Train Acc: 0.9999 | Val Loss: 0.3077, Val Acc: 0.9001
# Round 84/236 | Train Loss: 0.0119, Train Acc: 0.9999 | Val Loss: 0.3075, Val Acc: 0.9014
# Round 85/236 | Train Loss: 0.0115, Train Acc: 0.9999 | Val Loss: 0.3075, Val Acc: 0.9018
# Round 86/236 | Train Loss: 0.0111, Train Acc: 0.9999 | Val Loss: 0.3077, Val Acc: 0.9018
# Round 87/236 | Train Loss: 0.0107, Train Acc: 0.9999 | Val Loss: 0.3068, Val Acc: 0.9010
# Round 88/236 | Train Loss: 0.0104, Train Acc: 0.9999 | Val Loss: 0.3067, Val Acc: 0.9010
# Round 89/236 | Train Loss: 0.0101, Train Acc: 0.9999 | Val Loss: 0.3059, Val Acc: 0.9006
# Round 90/236 | Train Loss: 0.0098, Train Acc: 0.9999 | Val Loss: 0.3050, Val Acc: 0.9006
# Round 91/236 | Train Loss: 0.0095, Train Acc: 0.9999 | Val Loss: 0.3050, Val Acc: 0.9010
# Round 92/236 | Train Loss: 0.0092, Train Acc: 0.9999 | Val Loss: 0.3052, Val Acc: 0.9014
# Round 93/236 | Train Loss: 0.0089, Train Acc: 0.9999 | Val Loss: 0.3054, Val Acc: 0.9022
# Round 94/236 | Train Loss: 0.0086, Train Acc: 0.9999 | Val Loss: 0.3059, Val Acc: 0.9018
# Round 95/236 | Train Loss: 0.0084, Train Acc: 0.9999 | Val Loss: 0.3055, Val Acc: 0.9014
# Round 96/236 | Train Loss: 0.0081, Train Acc: 0.9999 | Val Loss: 0.3056, Val Acc: 0.9018
# Round 97/236 | Train Loss: 0.0079, Train Acc: 0.9999 | Val Loss: 0.3060, Val Acc: 0.9018
# Round 98/236 | Train Loss: 0.0077, Train Acc: 0.9999 | Val Loss: 0.3060, Val Acc: 0.9006
# Round 99/236 | Train Loss: 0.0075, Train Acc: 0.9999 | Val Loss: 0.3063, Val Acc: 0.9018
# Round 100/236 | Train Loss: 0.0073, Train Acc: 0.9999 | Val Loss: 0.3063, Val Acc: 0.9022
# Round 101/236 | Train Loss: 0.0070, Train Acc: 0.9999 | Val Loss: 0.3059, Val Acc: 0.9027
# Round 102/236 | Train Loss: 0.0069, Train Acc: 0.9999 | Val Loss: 0.3061, Val Acc: 0.9014
# Round 103/236 | Train Loss: 0.0067, Train Acc: 0.9999 | Val Loss: 0.3056, Val Acc: 0.9014
# Round 104/236 | Train Loss: 0.0065, Train Acc: 0.9999 | Val Loss: 0.3058, Val Acc: 0.9014
# Round 105/236 | Train Loss: 0.0063, Train Acc: 0.9999 | Val Loss: 0.3054, Val Acc: 0.9022
# Round 106/236 | Train Loss: 0.0062, Train Acc: 0.9999 | Val Loss: 0.3053, Val Acc: 0.9014
# Round 107/236 | Train Loss: 0.0060, Train Acc: 0.9999 | Val Loss: 0.3056, Val Acc: 0.9022
# Round 108/236 | Train Loss: 0.0059, Train Acc: 0.9999 | Val Loss: 0.3060, Val Acc: 0.9018
# Round 109/236 | Train Loss: 0.0058, Train Acc: 0.9999 | Val Loss: 0.3054, Val Acc: 0.9027
# Round 110/236 | Train Loss: 0.0056, Train Acc: 0.9999 | Val Loss: 0.3054, Val Acc: 0.9035
# Round 111/236 | Train Loss: 0.0055, Train Acc: 0.9999 | Val Loss: 0.3056, Val Acc: 0.9039
# Round 112/236 | Train Loss: 0.0054, Train Acc: 0.9999 | Val Loss: 0.3051, Val Acc: 0.9031
# Round 113/236 | Train Loss: 0.0052, Train Acc: 0.9999 | Val Loss: 0.3048, Val Acc: 0.9044
# Round 114/236 | Train Loss: 0.0051, Train Acc: 0.9999 | Val Loss: 0.3048, Val Acc: 0.9044
# Round 115/236 | Train Loss: 0.0050, Train Acc: 0.9999 | Val Loss: 0.3047, Val Acc: 0.9048
# Round 116/236 | Train Loss: 0.0049, Train Acc: 0.9999 | Val Loss: 0.3044, Val Acc: 0.9048
# Round 117/236 | Train Loss: 0.0048, Train Acc: 0.9999 | Val Loss: 0.3047, Val Acc: 0.9048
# Round 118/236 | Train Loss: 0.0047, Train Acc: 0.9999 | Val Loss: 0.3045, Val Acc: 0.9044
# Round 119/236 | Train Loss: 0.0046, Train Acc: 0.9999 | Val Loss: 0.3046, Val Acc: 0.9048
# Round 120/236 | Train Loss: 0.0045, Train Acc: 0.9999 | Val Loss: 0.3045, Val Acc: 0.9061
# Round 121/236 | Train Loss: 0.0044, Train Acc: 0.9999 | Val Loss: 0.3044, Val Acc: 0.9048
# Round 122/236 | Train Loss: 0.0043, Train Acc: 0.9999 | Val Loss: 0.3050, Val Acc: 0.9039
# Round 123/236 | Train Loss: 0.0042, Train Acc: 0.9999 | Val Loss: 0.3049, Val Acc: 0.9048
# Round 124/236 | Train Loss: 0.0041, Train Acc: 0.9999 | Val Loss: 0.3053, Val Acc: 0.9048
# Round 125/236 | Train Loss: 0.0041, Train Acc: 0.9999 | Val Loss: 0.3051, Val Acc: 0.9052
# Round 126/236 | Train Loss: 0.0040, Train Acc: 0.9999 | Val Loss: 0.3055, Val Acc: 0.9052
# Round 127/236 | Train Loss: 0.0039, Train Acc: 0.9999 | Val Loss: 0.3052, Val Acc: 0.9061
# Round 128/236 | Train Loss: 0.0038, Train Acc: 0.9999 | Val Loss: 0.3056, Val Acc: 0.9056
# Round 129/236 | Train Loss: 0.0038, Train Acc: 0.9999 | Val Loss: 0.3058, Val Acc: 0.9069
# Round 130/236 | Train Loss: 0.0037, Train Acc: 0.9999 | Val Loss: 0.3062, Val Acc: 0.9073
# Round 131/236 | Train Loss: 0.0036, Train Acc: 0.9999 | Val Loss: 0.3061, Val Acc: 0.9077
# Round 132/236 | Train Loss: 0.0036, Train Acc: 0.9999 | Val Loss: 0.3062, Val Acc: 0.9069
# Round 133/236 | Train Loss: 0.0035, Train Acc: 0.9999 | Val Loss: 0.3061, Val Acc: 0.9069
# Round 134/236 | Train Loss: 0.0035, Train Acc: 0.9999 | Val Loss: 0.3054, Val Acc: 0.9069
# Round 135/236 | Train Loss: 0.0034, Train Acc: 0.9999 | Val Loss: 0.3055, Val Acc: 0.9069
# Round 136/236 | Train Loss: 0.0034, Train Acc: 0.9999 | Val Loss: 0.3060, Val Acc: 0.9073
# Round 137/236 | Train Loss: 0.0033, Train Acc: 0.9999 | Val Loss: 0.3064, Val Acc: 0.9061
# Round 138/236 | Train Loss: 0.0032, Train Acc: 0.9999 | Val Loss: 0.3064, Val Acc: 0.9065
# Round 139/236 | Train Loss: 0.0032, Train Acc: 0.9999 | Val Loss: 0.3065, Val Acc: 0.9065
# Round 140/236 | Train Loss: 0.0031, Train Acc: 0.9999 | Val Loss: 0.3067, Val Acc: 0.9061
# Round 141/236 | Train Loss: 0.0031, Train Acc: 0.9999 | Val Loss: 0.3064, Val Acc: 0.9065
# Round 142/236 | Train Loss: 0.0030, Train Acc: 0.9999 | Val Loss: 0.3063, Val Acc: 0.9061
# Round 143/236 | Train Loss: 0.0030, Train Acc: 0.9999 | Val Loss: 0.3072, Val Acc: 0.9065
# Round 144/236 | Train Loss: 0.0030, Train Acc: 0.9999 | Val Loss: 0.3071, Val Acc: 0.9065
# Round 145/236 | Train Loss: 0.0029, Train Acc: 0.9999 | Val Loss: 0.3072, Val Acc: 0.9065
# Round 146/236 | Train Loss: 0.0029, Train Acc: 0.9999 | Val Loss: 0.3069, Val Acc: 0.9065
# Round 147/236 | Train Loss: 0.0028, Train Acc: 0.9999 | Val Loss: 0.3069, Val Acc: 0.9065
# Round 148/236 | Train Loss: 0.0028, Train Acc: 0.9999 | Val Loss: 0.3068, Val Acc: 0.9065
# Round 149/236 | Train Loss: 0.0028, Train Acc: 0.9999 | Val Loss: 0.3067, Val Acc: 0.9065
# Round 150/236 | Train Loss: 0.0027, Train Acc: 0.9999 | Val Loss: 0.3068, Val Acc: 0.9056
# Round 151/236 | Train Loss: 0.0027, Train Acc: 0.9999 | Val Loss: 0.3067, Val Acc: 0.9069
# Round 152/236 | Train Loss: 0.0026, Train Acc: 0.9999 | Val Loss: 0.3066, Val Acc: 0.9065
# Round 153/236 | Train Loss: 0.0026, Train Acc: 0.9999 | Val Loss: 0.3065, Val Acc: 0.9061
# Round 154/236 | Train Loss: 0.0026, Train Acc: 0.9999 | Val Loss: 0.3066, Val Acc: 0.9061
# Round 155/236 | Train Loss: 0.0025, Train Acc: 0.9999 | Val Loss: 0.3065, Val Acc: 0.9061
# Round 156/236 | Train Loss: 0.0025, Train Acc: 0.9999 | Val Loss: 0.3062, Val Acc: 0.9065
# Round 157/236 | Train Loss: 0.0025, Train Acc: 0.9999 | Val Loss: 0.3062, Val Acc: 0.9069
# Round 158/236 | Train Loss: 0.0024, Train Acc: 0.9999 | Val Loss: 0.3061, Val Acc: 0.9073
# Round 159/236 | Train Loss: 0.0024, Train Acc: 0.9999 | Val Loss: 0.3063, Val Acc: 0.9069
# Round 160/236 | Train Loss: 0.0024, Train Acc: 0.9999 | Val Loss: 0.3064, Val Acc: 0.9069
# Round 161/236 | Train Loss: 0.0024, Train Acc: 0.9999 | Val Loss: 0.3067, Val Acc: 0.9065
# Round 162/236 | Train Loss: 0.0023, Train Acc: 0.9999 | Val Loss: 0.3069, Val Acc: 0.9061
# Round 163/236 | Train Loss: 0.0023, Train Acc: 0.9999 | Val Loss: 0.3071, Val Acc: 0.9056
# Round 164/236 | Train Loss: 0.0023, Train Acc: 0.9999 | Val Loss: 0.3075, Val Acc: 0.9056
# Round 165/236 | Train Loss: 0.0022, Train Acc: 0.9999 | Val Loss: 0.3078, Val Acc: 0.9077
# Round 166/236 | Train Loss: 0.0022, Train Acc: 0.9999 | Val Loss: 0.3076, Val Acc: 0.9086
# Round 167/236 | Train Loss: 0.0022, Train Acc: 0.9999 | Val Loss: 0.3077, Val Acc: 0.9082
# Round 168/236 | Train Loss: 0.0022, Train Acc: 0.9999 | Val Loss: 0.3078, Val Acc: 0.9082
# Round 169/236 | Train Loss: 0.0021, Train Acc: 0.9999 | Val Loss: 0.3079, Val Acc: 0.9082
# Round 170/236 | Train Loss: 0.0021, Train Acc: 0.9999 | Val Loss: 0.3080, Val Acc: 0.9082
# Round 171/236 | Train Loss: 0.0021, Train Acc: 0.9999 | Val Loss: 0.3081, Val Acc: 0.9082
# Round 172/236 | Train Loss: 0.0021, Train Acc: 0.9999 | Val Loss: 0.3083, Val Acc: 0.9077
# Round 173/236 | Train Loss: 0.0021, Train Acc: 0.9999 | Val Loss: 0.3084, Val Acc: 0.9082
# Round 174/236 | Train Loss: 0.0020, Train Acc: 0.9999 | Val Loss: 0.3083, Val Acc: 0.9073
# Round 175/236 | Train Loss: 0.0020, Train Acc: 0.9999 | Val Loss: 0.3082, Val Acc: 0.9086
# Round 176/236 | Train Loss: 0.0020, Train Acc: 0.9999 | Val Loss: 0.3085, Val Acc: 0.9077
# Round 177/236 | Train Loss: 0.0020, Train Acc: 0.9999 | Val Loss: 0.3081, Val Acc: 0.9082
# Round 178/236 | Train Loss: 0.0020, Train Acc: 0.9999 | Val Loss: 0.3082, Val Acc: 0.9082
# Round 179/236 | Train Loss: 0.0019, Train Acc: 0.9999 | Val Loss: 0.3083, Val Acc: 0.9090
# Round 180/236 | Train Loss: 0.0019, Train Acc: 0.9999 | Val Loss: 0.3081, Val Acc: 0.9094
# Round 181/236 | Train Loss: 0.0019, Train Acc: 0.9999 | Val Loss: 0.3081, Val Acc: 0.9082
# Round 182/236 | Train Loss: 0.0019, Train Acc: 0.9999 | Val Loss: 0.3082, Val Acc: 0.9086
# Round 183/236 | Train Loss: 0.0019, Train Acc: 0.9999 | Val Loss: 0.3085, Val Acc: 0.9086
# Round 184/236 | Train Loss: 0.0019, Train Acc: 0.9999 | Val Loss: 0.3090, Val Acc: 0.9086
# Round 185/236 | Train Loss: 0.0018, Train Acc: 0.9999 | Val Loss: 0.3091, Val Acc: 0.9094
# Round 186/236 | Train Loss: 0.0018, Train Acc: 0.9999 | Val Loss: 0.3091, Val Acc: 0.9094
# Round 187/236 | Train Loss: 0.0018, Train Acc: 0.9999 | Val Loss: 0.3094, Val Acc: 0.9090
# Round 188/236 | Train Loss: 0.0018, Train Acc: 0.9999 | Val Loss: 0.3096, Val Acc: 0.9082
# Round 189/236 | Train Loss: 0.0018, Train Acc: 0.9999 | Val Loss: 0.3096, Val Acc: 0.9086
# Round 190/236 | Train Loss: 0.0018, Train Acc: 0.9999 | Val Loss: 0.3099, Val Acc: 0.9082
# Round 191/236 | Train Loss: 0.0017, Train Acc: 0.9999 | Val Loss: 0.3097, Val Acc: 0.9090
# Round 192/236 | Train Loss: 0.0017, Train Acc: 0.9999 | Val Loss: 0.3098, Val Acc: 0.9094
# Round 193/236 | Train Loss: 0.0017, Train Acc: 0.9999 | Val Loss: 0.3101, Val Acc: 0.9082
# Round 194/236 | Train Loss: 0.0017, Train Acc: 0.9999 | Val Loss: 0.3101, Val Acc: 0.9086
# Round 195/236 | Train Loss: 0.0017, Train Acc: 0.9999 | Val Loss: 0.3101, Val Acc: 0.9082
# Round 196/236 | Train Loss: 0.0017, Train Acc: 0.9999 | Val Loss: 0.3102, Val Acc: 0.9094
# Round 197/236 | Train Loss: 0.0017, Train Acc: 0.9999 | Val Loss: 0.3103, Val Acc: 0.9082
# Round 198/236 | Train Loss: 0.0016, Train Acc: 0.9999 | Val Loss: 0.3102, Val Acc: 0.9094
# Round 199/236 | Train Loss: 0.0016, Train Acc: 0.9999 | Val Loss: 0.3101, Val Acc: 0.9094
# Round 200/236 | Train Loss: 0.0016, Train Acc: 0.9999 | Val Loss: 0.3099, Val Acc: 0.9086
# Round 201/236 | Train Loss: 0.0016, Train Acc: 0.9999 | Val Loss: 0.3099, Val Acc: 0.9086
# Round 202/236 | Train Loss: 0.0016, Train Acc: 0.9999 | Val Loss: 0.3101, Val Acc: 0.9090
# Round 203/236 | Train Loss: 0.0016, Train Acc: 0.9999 | Val Loss: 0.3101, Val Acc: 0.9094
# Round 204/236 | Train Loss: 0.0016, Train Acc: 0.9999 | Val Loss: 0.3103, Val Acc: 0.9094
# Round 205/236 | Train Loss: 0.0016, Train Acc: 0.9999 | Val Loss: 0.3104, Val Acc: 0.9094
# Round 206/236 | Train Loss: 0.0016, Train Acc: 0.9999 | Val Loss: 0.3104, Val Acc: 0.9103
# Round 207/236 | Train Loss: 0.0015, Train Acc: 0.9999 | Val Loss: 0.3103, Val Acc: 0.9103
# Round 208/236 | Train Loss: 0.0015, Train Acc: 0.9999 | Val Loss: 0.3101, Val Acc: 0.9107
# Round 209/236 | Train Loss: 0.0015, Train Acc: 0.9999 | Val Loss: 0.3100, Val Acc: 0.9111
# Round 210/236 | Train Loss: 0.0015, Train Acc: 0.9999 | Val Loss: 0.3101, Val Acc: 0.9103
# Round 211/236 | Train Loss: 0.0015, Train Acc: 0.9999 | Val Loss: 0.3101, Val Acc: 0.9107
# Round 212/236 | Train Loss: 0.0015, Train Acc: 0.9999 | Val Loss: 0.3102, Val Acc: 0.9111
# Round 213/236 | Train Loss: 0.0015, Train Acc: 0.9999 | Val Loss: 0.3101, Val Acc: 0.9111
# Round 214/236 | Train Loss: 0.0015, Train Acc: 0.9999 | Val Loss: 0.3102, Val Acc: 0.9107
# Round 215/236 | Train Loss: 0.0015, Train Acc: 0.9999 | Val Loss: 0.3105, Val Acc: 0.9107
# Round 216/236 | Train Loss: 0.0015, Train Acc: 0.9999 | Val Loss: 0.3107, Val Acc: 0.9111
# Round 217/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3111, Val Acc: 0.9107
# Round 218/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3110, Val Acc: 0.9107
# Round 219/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3112, Val Acc: 0.9107
# Round 220/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3113, Val Acc: 0.9107
# Round 221/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3113, Val Acc: 0.9107
# Round 222/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3111, Val Acc: 0.9107
# Round 223/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3115, Val Acc: 0.9103
# Round 224/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3114, Val Acc: 0.9103
# Round 225/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3113, Val Acc: 0.9103
# Round 226/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3112, Val Acc: 0.9107
# Round 227/236 | Train Loss: 0.0014, Train Acc: 0.9999 | Val Loss: 0.3110, Val Acc: 0.9103
# Round 228/236 | Train Loss: 0.0013, Train Acc: 0.9999 | Val Loss: 0.3110, Val Acc: 0.9107
# Round 229/236 | Train Loss: 0.0013, Train Acc: 0.9999 | Val Loss: 0.3112, Val Acc: 0.9116
# Round 230/236 | Train Loss: 0.0013, Train Acc: 0.9999 | Val Loss: 0.3112, Val Acc: 0.9128
# Round 231/236 | Train Loss: 0.0013, Train Acc: 0.9999 | Val Loss: 0.3113, Val Acc: 0.9124
# Round 232/236 | Train Loss: 0.0013, Train Acc: 0.9999 | Val Loss: 0.3115, Val Acc: 0.9124
# Round 233/236 | Train Loss: 0.0013, Train Acc: 0.9999 | Val Loss: 0.3115, Val Acc: 0.9132
# Round 234/236 | Train Loss: 0.0013, Train Acc: 0.9999 | Val Loss: 0.3117, Val Acc: 0.9128
# Round 235/236 | Train Loss: 0.0013, Train Acc: 0.9999 | Val Loss: 0.3119, Val Acc: 0.9124
# Round 236/236 | Train Loss: 0.0013, Train Acc: 0.9999 | Val Loss: 0.3119, Val Acc: 0.9120

# %%
import time

# --- Define the path to your test data ---
test_dir = "/content/dataset/Test"

# --- Create the test dataset and dataloader ---
test_dataset = datasets.ImageFolder(test_dir, transform=data_transforms)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# --- Extract and save features for the test set ---
print("Extracting features from the test set...")
start_time = time.time()

X_test, y_test = extract_features(test_loader, feature_extractor, device)

end_time = time.time()
print(f"Feature extraction for test set took: {end_time - start_time:.2f} seconds")

print(f"Test features shape: {X_test.shape}")

# --- Save features for later use ---
np.save('X_test.npy', X_test)
np.save('y_test.npy', y_test)
print("✅ Test features saved!")
# Out:
# Extracting features from the test set...
# Extracting features:   1%|▏         | 1/74 [00:00<00:46,  1.56it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Extracting features: 100%|██████████| 74/74 [00:47<00:00,  1.56it/s]
# Feature extraction for test set took: 47.34 seconds
# Test features shape: (2364, 1792)
# ✅ Test features saved!

# %%
import numpy as np
import time
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, log_loss

# --- Load the test set features ---
X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")

# --- Create the DMatrix for the test set ---
dtest = xgb.DMatrix(X_test, label=y_test)

# --- Helper function to calculate TPR and FPR from a confusion matrix ---
def calculate_tpr_fpr(cm):
    """Calculates macro-average TPR and FPR for a multi-class confusion matrix."""
    num_classes = cm.shape[0]
    tpr_list = []
    fpr_list = []

    for i in range(num_classes):
        tp = cm[i, i]
        fn = np.sum(cm[i, :]) - tp
        fp = np.sum(cm[:, i]) - tp
        tn = np.sum(cm) - (tp + fn + fp)

        # True Positive Rate (Recall)
        tpr = tp / (tp + fn) if (tp + fn) > 0 else 0.
        tpr_list.append(tpr)

        # False Positive Rate
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.
        fpr_list.append(fpr)

    return np.mean(tpr_list), np.mean(fpr_list)


# ===================================================================
#                       PERFORMANCE EVALUATION
# ===================================================================

# Get the class names from the dataset folder structure
class_names = train_dataset.classes

# --- Get predictions (probabilities and final labels) ---
# Training Set
train_start_time = time.time()
y_train_pred_proba = model.predict(dtrain)
train_pred_time = time.time() - train_start_time
y_train_pred = np.argmax(y_train_pred_proba, axis=1)

# Validation Set
valid_start_time = time.time()
y_valid_pred_proba = model.predict(dvalid)
valid_pred_time = time.time() - valid_start_time
y_valid_pred = np.argmax(y_valid_pred_proba, axis=1)

# Testing Set
test_start_time = time.time()
y_test_pred_proba = model.predict(dtest)
test_pred_time = time.time() - test_start_time
y_test_pred = np.argmax(y_test_pred_proba, axis=1)


# --- Calculate Metrics ---
# Training
report_train = classification_report(y_train, y_train_pred, target_names=class_names, output_dict=True)
cm_train = confusion_matrix(y_train, y_train_pred)
tpr_train, fpr_train = calculate_tpr_fpr(cm_train)
loss_train = evals_result['train']['mlogloss'][-1] # Get final loss from training history

# Validation
report_valid = classification_report(y_valid, y_valid_pred, target_names=class_names, output_dict=True)
cm_valid = confusion_matrix(y_valid, y_valid_pred)
tpr_valid, fpr_valid = calculate_tpr_fpr(cm_valid)
loss_valid = evals_result['valid']['mlogloss'][-1] # Get final loss from training history

# Testing
report_test = classification_report(y_test, y_test_pred, target_names=class_names, output_dict=True)
cm_test = confusion_matrix(y_test, y_test_pred)
tpr_test, fpr_test = calculate_tpr_fpr(cm_test)
loss_test = log_loss(y_test, y_test_pred_proba) # Calculate test loss manually
auroc_test = roc_auc_score(y_test, y_test_pred_proba, multi_class='ovr', average='weighted')


# --- Print Final Reports ---

print("="*50)
print("          TRAINING SET METRICS")
print("="*50)
print(f"Accuracy:          {report_train['accuracy']:.4f}")
print(f"Weighted Precision:  {report_train['weighted avg']['precision']:.4f}")
print(f"Weighted Recall/TPR: {report_train['weighted avg']['recall']:.4f}")
print(f"Weighted F1-Score:   {report_train['weighted avg']['f1-score']:.4f}")
print(f"Macro Avg FPR:       {fpr_train:.4f}")
print(f"Final Loss:          {loss_train:.4f}")
# Note: Training time is the time for the entire xgb.train() call
print(f"Inference Time:      {train_pred_time:.4f} seconds\n")


print("="*50)
print("         VALIDATION SET METRICS")
print("="*50)
print(f"Accuracy:          {report_valid['accuracy']:.4f}")
print(f"Weighted Precision:  {report_valid['weighted avg']['precision']:.4f}")
print(f"Weighted Recall/TPR: {report_valid['weighted avg']['recall']:.4f}")
print(f"Weighted F1-Score:   {report_valid['weighted avg']['f1-score']:.4f}")
print(f"Macro Avg FPR:       {fpr_valid:.4f}")
print(f"Final Loss:          {loss_valid:.4f}")
print(f"Validation Time:     {valid_pred_time:.4f} seconds\n")


print("="*50)
print("           TESTING SET METRICS")
print("="*50)
print(f"Accuracy:          {report_test['accuracy']:.4f}")
print(f"Weighted Precision:  {report_test['weighted avg']['precision']:.4f}")
print(f"Weighted Recall/TPR: {report_test['weighted avg']['recall']:.4f}")
print(f"Weighted F1-Score:   {report_test['weighted avg']['f1-score']:.4f}")
print(f"Macro Avg FPR:       {fpr_test:.4f}")
print(f"Weighted AUROC:      {auroc_test:.4f}")
print(f"Final Loss:          {loss_test:.4f}")
print(f"Testing Time:        {test_pred_time:.4f} seconds\n")
# Out:
# ==================================================
#           TRAINING SET METRICS
# ==================================================
# Accuracy:          0.9999
# Weighted Precision:  0.9999
# Weighted Recall/TPR: 0.9999
# Weighted F1-Score:   0.9999
# Macro Avg FPR:       0.0000
# Final Loss:          0.0013
# Inference Time:      0.0023 seconds
#
# ==================================================
#          VALIDATION SET METRICS
# ==================================================
# Accuracy:          0.9120
# Weighted Precision:  0.9123
# Weighted Recall/TPR: 0.9120
# Weighted F1-Score:   0.9120
# Macro Avg FPR:       0.0110
# Final Loss:          0.3119
# Validation Time:     0.0005 seconds
#
# ==================================================
#            TESTING SET METRICS
# ==================================================
# Accuracy:          0.9027
# Weighted Precision:  0.9029
# Weighted Recall/TPR: 0.9027
# Weighted F1-Score:   0.9027
# Macro Avg FPR:       0.0122
# Weighted AUROC:      0.9927
# Final Loss:          0.3393
# Testing Time:        0.1251 seconds

# %%
import shap

# Ensure the model and feature extractor are on the correct device
feature_extractor.to(device)
feature_extractor.eval()

# 1. Define the prediction function for SHAP
def predict_proba_shap(images_numpy):
    # images_numpy will be a numpy array from SHAP. Convert to tensor.
    images_tensor = torch.from_numpy(images_numpy).float().permute(0, 3, 1, 2) # SHAP expects (N, H, W, C), PyTorch needs (N, C, H, W)

    # Apply normalization (assuming it was part of data_transforms originally)
    # The Normalize transform expects tensor input
    # Re-apply transforms if feature_extractor expects raw images, or assume pre-processed for SHAP
    # For simplicity here, let's assume images_tensor is already normalized or handle it in the function if needed.
    # However, since the HybridFeatureExtractor was designed to work with resized, normalized images,
    # the SHAP explainer should receive images that have undergone appropriate preprocessing.

    # For this demonstration, we'll assume the input `images_numpy` to `predict_proba_shap`
    # already has the correct pixel values (e.g., 0-1 range) but still needs normalization.
    # Let's recreate the normalization part of the transform.
    normalize = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    images_tensor = normalize(images_tensor)

    with torch.no_grad():
        images_tensor = images_tensor.to(device)
        features = feature_extractor(images_tensor)

    # Convert features to DMatrix for XGBoost prediction
    d_features = xgb.DMatrix(features.cpu().numpy())

    # Get probabilities from XGBoost model
    probabilities = model.predict(d_features)
    return probabilities

# 2. Select background data for KernelExplainer
# For image data, SHAP often uses a small subset of training images or a blurred version
# to represent the background. We need raw images for the prediction function.

# Get a few background images from the training set (e.g., 50 random samples)
num_background_samples = 50
sampled_indices = np.random.choice(len(train_dataset), num_background_samples, replace=False)
background_images_list = []
for i in sampled_indices:
    # Get the raw image (before ToTensor and Normalize) and transform it
    # into a tensor that `predict_proba_shap` expects after its own internal processing.
    # The `data_transforms` includes Resize, ToTensor, Normalize.
    # SHAP explainer will pass numpy arrays of images, so the predict_proba_shap
    # needs to handle the conversion to tensor and normalization again.

    # For the background data, we need to pass images that are ready to be converted
    # to the format that predict_proba_shap expects *before* its internal normalization.
    # So, we retrieve the raw PIL image, convert it to numpy, and resize it as the first step.

    # We need to get the image without ToTensor and Normalize for the background.
    # Let's get the PIL image, then resize it and convert to numpy.
    pil_image, _ = train_dataset.samples[i] # Get PIL image and label

    # Apply the initial Resize to the PIL image
    resized_image = transforms.Resize((256, 256))(pil_image)

    # Convert to numpy array (H, W, C) for SHAP background
    # SHAP's KernelExplainer expects (N, H, W, C) for image inputs
    background_images_list.append(np.array(resized_image))

background_images_numpy = np.array(background_images_list)

print(f"Shape of background images for SHAP: {background_images_numpy.shape}")

# Initialize KernelExplainer
# The prediction function needs to handle the numpy to tensor conversion and normalization.
explainer = shap.KernelExplainer(predict_proba_shap, background_images_numpy)

# 3. Select samples for explanation from the test set (e.g., 5 random samples)
num_explanation_samples = 5
sampled_test_indices = np.random.choice(len(test_dataset), num_explanation_samples, replace=False)

explanation_images_list = []
explanation_labels_list = []
for i in sampled_test_indices:
    pil_image, label = test_dataset.samples[i]
    resized_image = transforms.Resize((256, 256))(pil_image)
    explanation_images_list.append(np.array(resized_image))
    explanation_labels_list.append(label)

explanation_images_numpy = np.array(explanation_images_list)

print(f"Shape of explanation images for SHAP: {explanation_images_numpy.shape}")
print("Calculating SHAP values... This may take a while.")

# Compute SHAP values
shap_values = explainer.shap_values(explanation_images_numpy, nsamples='auto')

print("SHAP values calculated.")

# Get class names for plotting
class_names = test_dataset.classes

# Visualize SHAP explanations
print("\nVisualizing SHAP explanations:")
for i in range(num_explanation_samples):
    print(f"Explanation for test sample {i+1} (True Class: {class_names[explanation_labels_list[i]]})")
    # Use the `idx` parameter to specify which class to explain for a multi-output model
    # For multi-class, shap.image_plot usually shows explanations for all classes by default
    # or allows specifying a class index. Here, we'll plot for the predicted class.

    # Predict the class for this specific image to plot SHAP values for it
    single_image_tensor = normalize(transforms.ToTensor()(transforms.Resize((256,256))(test_dataset.samples[sampled_test_indices[i]][0]))).unsqueeze(0).to(device)
    single_feature = feature_extractor(single_image_tensor)
    single_d_feature = xgb.DMatrix(single_feature.cpu().numpy())
    predicted_proba = model.predict(single_d_feature)
    predicted_class_idx = np.argmax(predicted_proba)
    predicted_class_name = class_names[predicted_class_idx]

    print(f"Predicted Class: {predicted_class_name}")

    # shap.image_plot expects images in (N, H, W, C) format
    # It expects shap_values as a list of arrays, one for each output class
    # And the original image in (H, W, C) format
    shap.image_plot(
        shap_values[predicted_class_idx][i:i+1], # SHAP values for the predicted class for this sample
        explanation_images_numpy[i:i+1],         # The original image
        labels=[predicted_class_name],           # Label for the predicted class
        true_labels=[class_names[explanation_labels_list[i]]]
    )
