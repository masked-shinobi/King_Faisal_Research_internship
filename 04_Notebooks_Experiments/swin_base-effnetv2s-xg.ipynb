# %%
pip install timm
# Out:
# Collecting timm
#   Downloading timm-1.0.21-py3-none-any.whl.metadata (62 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from timm) (2.8.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm) (0.23.0+cu128)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm) (6.0.3)
# Collecting huggingface_hub (from timm)
#   Downloading huggingface_hub-1.0.0-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors (from timm)
#   Using cached safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2024.6.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (25.0)
# Collecting shellingham (from huggingface_hub->timm)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.67.1)
# Collecting typer-slim (from huggingface_hub->timm)
#   Downloading typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.15.0)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface_hub->timm)
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub->timm) (1.3.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->timm) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->timm) (3.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (11.0.0)
# Collecting click>=8.0.0 (from typer-slim->huggingface_hub->timm)
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Downloading timm-1.0.21-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 45.3 MB/s  0:00:00
# Downloading huggingface_hub-1.0.0-py3-none-any.whl (503 kB)
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 33.8 MB/s  0:00:00
# Using cached safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typer_slim-0.20.0-py3-none-any.whl (47 kB)
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
# Installing collected packages: shellingham, safetensors, hf-xet, click, typer-slim, huggingface_hub, timm
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [timm]6/7 [timm]ngface_hub]
# Successfully installed click-8.3.0 hf-xet-1.2.0 huggingface_hub-1.0.0 safetensors-0.6.2 shellingham-1.5.4 timm-1.0.21 typer-slim-0.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# ==============================================================================
# PART 1: HYBRID FEATURE EXTRACTION (GPU REQUIRED)
# Switching to stable LeViT-256 to fix positional embedding mismatch
# ==============================================================================

import os
import time
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import timm
import numpy as np
from tqdm import tqdm

# --- Configuration (UPDATED) ---
DATA_ROOT = "/workspace/" 
TRAIN_PATH = os.path.join(DATA_ROOT, "Train")
VALID_PATH = os.path.join(DATA_ROOT, "Valid")
TEST_PATH = os.path.join(DATA_ROOT, "Test")

BATCH_SIZE = 64
NUM_WORKERS = 4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")

# *** CRITICAL CHANGE: SWITCH TO A STABLE IMAGE SIZE ***
NORM_MEAN = [0.485, 0.456, 0.406]
NORM_STD = [0.229, 0.224, 0.225]
IMAGE_SIZE = 224 # <--- Changed from 384 to 256 for stable LeViT-256 weights 

# --- Data Transformation ---
necessary_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)), # Now 256x256
    transforms.ToTensor(),
    transforms.Normalize(mean=NORM_MEAN, std=NORM_STD)
])

# --- 1. Load Datasets Directly from Separate Folders ---
print(f"Loading data from: {DATA_ROOT}")
train_set = datasets.ImageFolder(TRAIN_PATH, transform=necessary_transform)
val_set = datasets.ImageFolder(VALID_PATH, transform=necessary_transform)
test_set = datasets.ImageFolder(TEST_PATH, transform=necessary_transform)

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
print(f"Train samples: {len(train_set)}, Valid samples: {len(val_set)}, Test samples: {len(test_set)}")


# --- 2. Hybrid Feature Extractor Model (ViT-Base Update) ---
class HybridFeatureExtractor(nn.Module):
    """Fuses features from ViT-Base and EfficientNetV2-S."""
    def __init__(self):
        super().__init__()
        
        # 1. ViT-Base branch (Vision Transformer) - NEW MODEL
        self.vit = timm.create_model(
            'swin_base_patch4_window7_224', # <--- TARGET MODEL
            pretrained=True, 
            num_classes=0, 
            img_size=IMAGE_SIZE 
        )
        
        # 2. EfficientNetV2-S branch (CNN) - REMAINS THE SAME
        self.efficientnet = timm.create_model('tf_efficientnetv2_s', pretrained=True, num_classes=0)

    def forward(self, x):
        vit_features = self.vit(x) # Use self.vit
        efficient_features = self.efficientnet(x)
        # Feature Fusion
        combined_features = torch.cat((vit_features, efficient_features), dim=1)
        return combined_features

# --- 3. Feature Extraction Function ---
def extract_features(data_loader, split_name):
    """Extracts features and records time."""
    start_time = time.time()
    model.eval()
    all_features = []
    all_labels = []
    
    print(f"Starting feature extraction for {split_name}...")
    with torch.no_grad():
        for images, labels in tqdm(data_loader):
            images = images.to(DEVICE)
            features = model(images).cpu().numpy()
            all_features.append(features)
            all_labels.extend(labels.tolist())

    features_matrix = np.concatenate(all_features, axis=0)
    labels_array = np.array(all_labels)
    elapsed_time = time.time() - start_time
    
    return features_matrix, labels_array, elapsed_time

# Instantiate Model
model = HybridFeatureExtractor().to(DEVICE)

# Run Extraction for all splits
X_train, y_train, train_time_feat = extract_features(train_loader, "Training")
X_val, y_val, val_time_feat = extract_features(val_loader, "Validation")
X_test, y_test, test_time_feat = extract_features(test_loader, "Testing")

print(f"\nFeature Extraction Times:")
print(f"Train Feat Time: {train_time_feat:.2f}s | Val Feat Time: {val_time_feat:.2f}s | Test Feat Time: {test_time_feat:.2f}s")

# Save Extracted Features
np.save(os.path.join(DATA_ROOT, 'X_train.npy'), X_train)
np.save(os.path.join(DATA_ROOT, 'y_train.npy'), y_train)
np.save(os.path.join(DATA_ROOT, 'X_valid.npy'), X_val)
np.save(os.path.join(DATA_ROOT, 'y_valid.npy'), y_val)
np.save(os.path.join(DATA_ROOT, 'X_test.npy'), X_test)
np.save(os.path.join(DATA_ROOT, 'y_test.npy'), y_test)
# Out:
# Using device: cuda
# Loading data from: /workspace/
# Train samples: 18898, Valid samples: 2362, Test samples: 2364
# Starting feature extraction for Training...
#   0%|          | 0/296 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#   2%|▏         | 5/296 [00:01<01:17,  3.75it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#   3%|▎         | 10/296 [00:02<00:50,  5.65it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  10%|▉         | 29/296 [00:07<00:56,  4.71it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 100%|██████████| 296/296 [01:07<00:00,  4.38it/s]
# Starting feature extraction for Validation...
#   0%|          | 0/37 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#   8%|▊         | 3/37 [00:01<00:11,  2.93it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  49%|████▊     | 18/37 [00:06<00:13,  1.39it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 100%|██████████| 37/37 [00:10<00:00,  3.53it/s]
# Starting feature extraction for Testing...
#   0%|          | 0/37 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  11%|█         | 4/37 [00:01<00:10,  3.29it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  38%|███▊      | 14/37 [00:04<00:05,  4.11it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 100%|██████████| 37/37 [00:09<00:00,  4.09it/s]
# Feature Extraction Times:
# Train Feat Time: 67.65s | Val Feat Time: 10.50s | Test Feat Time: 9.08s

# %%
import optuna
import xgboost as xgb
import numpy as np
import time
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, log_loss, 
    roc_auc_score, confusion_matrix, classification_report
)

# --- CONFIGURATION ---
DATA_ROOT = "/workspace/"
N_TRIALS = 100 
SEED = 42

# --- 1. Utility Functions: Data Loading & Scaling ---
def load_and_scale_features(data_root):
    """Loads features from .npy files and applies StandardScaler."""
    
    X_train = np.load(os.path.join(data_root, 'X_train.npy'))
    y_train = np.load(os.path.join(data_root, 'y_train.npy'))
    X_val = np.load(os.path.join(data_root, 'X_valid.npy'))
    y_val = np.load(os.path.join(data_root, 'y_valid.npy'))
    X_test = np.load(os.path.join(data_root, 'X_test.npy'))
    y_test = np.load(os.path.join(data_root, 'y_test.npy'))

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test) 

    # Convert labels to integer codes
    all_labels = pd.Series(np.concatenate([y_train, y_val, y_test]))
    label_map = {label: code for code, label in enumerate(all_labels.astype('category').cat.categories)}
    
    y_train_int = np.array([label_map[label] for label in y_train])
    y_val_int = np.array([label_map[label] for label in y_val])
    y_test_int = np.array([label_map[label] for label in y_test])
    
    num_classes = len(label_map)

    return X_train_scaled, y_train_int, X_val_scaled, y_val_int, X_test_scaled, y_test_int, num_classes, scaler


# --- 2. Utility Functions: Metric Calculation ---
def calculate_metrics(y_true, y_pred, y_prob, phase=""):
    """Calculates all required classification metrics."""
    metrics = {}
    
    # Standard Metrics (Macro Average)
    metrics[f'{phase} Accuracy'] = accuracy_score(y_true, y_pred)
    metrics[f'{phase} Precision'] = precision_score(y_true, y_pred, average='macro', zero_division=0)
    metrics[f'{phase} Recall'] = recall_score(y_true, y_pred, average='macro', zero_division=0)
    metrics[f'{phase} F1 Score'] = f1_score(y_true, y_pred, average='macro', zero_division=0)
    
    # Loss and AUROC (Requires probabilities)
    metrics[f'{phase} Loss'] = log_loss(y_true, y_prob)
    metrics[f'{phase} AUROC'] = roc_auc_score(y_true, y_prob, multi_class='ovo', average='macro')

    # Calculate TPR and FPR (True/False Positive Rate) - Macro Averaged
    cm = confusion_matrix(y_true, y_pred)
    FP = cm.sum(axis=0) - np.diag(cm)  
    FN = cm.sum(axis=1) - np.diag(cm)
    TP = np.diag(cm)
    TN = cm.sum() - (FP + FN + TP)
    
    epsilon = 1e-7
    TPR_macro = np.mean(TP / (TP + FN + epsilon)) 
    FPR_macro = np.mean(FP / (FP + TN + epsilon))

    metrics[f'{phase} TPR'] = TPR_macro
    metrics[f'{phase} FPR'] = FPR_macro
    
    return metrics


# --- 3. Optuna Objective Function (using xgb.train) ---
def objective(trial, X_train, y_train, X_val, y_val, num_classes):
    """XGBoost HPO objective function for Optuna using core API."""
    
    # 1. Define DMatrices for core API
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)

    # 2. Define the search space
    param = {
        'objective': 'multi:softprob',
        'eval_metric': 'mlogloss',
        'tree_method': 'hist', # Use 'exact' method with GPU
        'device': 'cuda',       # Explicitly set device to CUDA
        'num_class': num_classes,
        'verbosity': 0,                        
        'n_jobs': -1,                          
        'seed': SEED,
        
        # TPE Search Parameters
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'max_depth': trial.suggest_int('max_depth', 5, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 15),
    }
    
    n_estimators = param.pop('n_estimators')

    # 3. Train using core API (xgb.train)
    model = xgb.train(
        param, 
        dtrain, 
        num_boost_round=n_estimators, 
        evals=[(dval, 'validation')], 
        early_stopping_rounds=30, 
        verbose_eval=False
    )
    
    # 4. Predict probabilities and find best iteration
    y_prob_val = model.predict(dval, iteration_range=(0, model.best_iteration))
    y_pred_val = np.argmax(y_prob_val, axis=1) 
    
    # Optimization target: Validation F1 Score (Macro)
    f1 = f1_score(y_val, y_pred_val, average='macro', zero_division=0)
    
    return f1

# --- 4. Main Execution (HPO and Final Evaluation) ---
def main():
    print(f"--- SWIN-BASE HPO INITIATED ---")

    # Load and scale data
    X_train, y_train, X_val, y_val, X_test, y_test, num_classes, scaler = load_and_scale_features(DATA_ROOT)
    print(f"Data Loaded: {X_train.shape[0]} training samples, {num_classes} classes.")

    # --- HPO Run ---
    start_time_hpo = time.time()
    study = optuna.create_study(
        direction='maximize', 
        sampler=optuna.samplers.TPESampler(seed=SEED), 
        study_name='swin_base_hpo_xgb'
    )

    # ADDED PROGRESS BAR HERE
    study.optimize(
        lambda trial: objective(trial, X_train, y_train, X_val, y_val, num_classes), 
        n_trials=N_TRIALS,
        show_progress_bar=True 
    )
    # END PROGRESS BAR

    time_hpo = time.time() - start_time_hpo
    print(f"Optuna HPO complete in {time_hpo:.2f} seconds.")

    best_params_raw = study.best_params
    best_n_estimators = best_params_raw.pop('n_estimators')
    
    best_params = {
            **best_params_raw,
            'objective': 'multi:softprob',
            'eval_metric': 'mlogloss',
            'tree_method': 'hist', # Use 'exact' method with GPU
            'device': 'cuda',       # Explicitly set device to CUDA
            'num_class': num_classes,
            'verbosity': 0,
            'seed': SEED
        }
    
    print("\nBest Hyperparameters Found (Optuna):")
    for key, value in best_params_raw.items():
        print(f"  {key}: {value}")
    print(f"  n_estimators (Best): {best_n_estimators}")

    # --- Final Model Training (Step 3) ---
    
    # Combine Train and Validation data for final training
    X_final_train = np.concatenate([X_train, X_val])
    y_final_train = np.concatenate([y_train, y_val])
    
    # Create final DMatrix
    dfinal_train = xgb.DMatrix(X_final_train, label=y_final_train)

    # Train Final Model (Measure training time)
    start_time_final_train = time.time()
    final_model = xgb.train(
        best_params,
        dfinal_train,
        num_boost_round=best_n_estimators
    )
    time_final_train = time.time() - start_time_final_train
    print(f"Final Model trained on (Train + Val) in {time_final_train:.4f} seconds.")


    # --- METRIC CALCULATION ---
    all_metrics = {}
    
    # Feature extraction times from your Part 1 run
    # Train Feat Time: 72.39s | Val Feat Time: 10.41s | Test Feat Time: 8.82s
    train_time_feat = 72.39
    val_time_feat = 10.41
    test_time_feat = 8.82
    
    # Create DMatrices for prediction
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)
    dtest = xgb.DMatrix(X_test, label=y_test)

    # 1. Training Metrics
    start_time_train_eval = time.time()
    y_train_prob = final_model.predict(dtrain)
    y_train_pred = np.argmax(y_train_prob, axis=1)
    
    all_metrics.update(calculate_metrics(y_train, y_train_pred, y_train_prob, "Training"))
    all_metrics['Training Time (s)'] = time_final_train + train_time_feat 
    
    # 2. Validation Metrics
    start_time_val_eval = time.time()
    y_val_prob = final_model.predict(dval)
    y_val_pred = np.argmax(y_val_prob, axis=1)
    
    all_metrics.update(calculate_metrics(y_val, y_val_pred, y_val_prob, "Validation"))
    all_metrics['Validation Time (s)'] = (time.time() - start_time_val_eval) + val_time_feat 
    
    # 3. Test Metrics
    start_time_test_eval = time.time()
    y_test_prob = final_model.predict(dtest)
    y_test_pred = np.argmax(y_test_prob, axis=1)
    
    all_metrics.update(calculate_metrics(y_test, y_test_pred, y_test_prob, "Testing"))
    all_metrics['Testing Time (s)'] = (time.time() - start_time_test_eval) + test_time_feat 

    
    # --- FINAL OUTPUT ---
    print("\n" + "="*80)
    print("COMPLETE HPO PERFORMANCE REPORT (Swin-base Hybrid + XGBoost)")
    print("="*80)
    
    # Define the exact order of metrics for clear reporting
    metric_order = [
        'Training Accuracy', 'Training Precision', 'Training Recall', 'Training F1 Score', 'Training Loss', 'Training TPR', 'Training FPR', 'Training Time (s)',
        'Validation Accuracy', 'Validation Precision', 'Validation Recall', 'Validation F1 Score', 'Validation Loss', 'Validation TPR', 'Validation FPR', 'Validation Time (s)',
        'Testing Accuracy', 'Testing Precision', 'Testing Recall', 'Testing F1 Score', 'Testing Loss', 'Testing TPR', 'Testing FPR', 'Testing AUROC', 'Testing Time (s)'
    ]

    for metric in metric_order:
        if metric in all_metrics:
            value = all_metrics[metric]
            if 'Time' in metric:
                print(f"{metric:<30} {value:.4f}")
            else:
                print(f"{metric:<30} {value:.6f}")

    print("\n" + "-"*30 + " TESTING CLASSIFICATION REPORT " + "-"*30)
    print(classification_report(y_test, y_test_pred, zero_division=0))

if __name__ == '__main__':
    main()
# Out:
# --- SWIN-BASE HPO INITIATED ---
# [I 2025-10-27 20:11:37,080] A new study created in memory with name: swin_base_hpo_xgb
# Data Loaded: 18898 training samples, 9 classes.
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-27 20:12:04,817] Trial 0 finished with value: 0.9481871858541476 and parameters: {'n_estimators': 400, 'max_depth': 15, 'learning_rate': 0.08960785365368121, 'reg_alpha': 0.0024430162614261413, 'reg_lambda': 2.5361081166471375e-07, 'subsample': 0.662397808134481, 'colsample_bytree': 0.6232334448672797, 'min_child_weight': 13}. Best is trial 0 with value: 0.9481871858541476.
# [I 2025-10-27 20:14:36,623] Trial 1 finished with value: 0.9376350287261125 and parameters: {'n_estimators': 700, 'max_depth': 12, 'learning_rate': 0.010636066512540286, 'reg_alpha': 5.360294728728285, 'reg_lambda': 0.31044435499483225, 'subsample': 0.6849356442713105, 'colsample_bytree': 0.6727299868828402, 'min_child_weight': 3}. Best is trial 0 with value: 0.9481871858541476.
# [I 2025-10-27 20:15:35,994] Trial 2 finished with value: 0.9448086527985092 and parameters: {'n_estimators': 400, 'max_depth': 10, 'learning_rate': 0.03647316284911211, 'reg_alpha': 4.17890272377219e-06, 'reg_lambda': 0.0032112643094417484, 'subsample': 0.6557975442608167, 'colsample_bytree': 0.7168578594140873, 'min_child_weight': 6}. Best is trial 0 with value: 0.9481871858541476.
# [I 2025-10-27 20:17:43,844] Trial 3 finished with value: 0.9411781447786337 and parameters: {'n_estimators': 500, 'max_depth': 13, 'learning_rate': 0.018187859051288217, 'reg_alpha': 0.00042472707398058225, 'reg_lambda': 0.0021465011216654484, 'subsample': 0.6185801650879991, 'colsample_bytree': 0.8430179407605753, 'min_child_weight': 3}. Best is trial 0 with value: 0.9481871858541476.
# [I 2025-10-27 20:17:58,310] Trial 4 finished with value: 0.941397732514226 and parameters: {'n_estimators': 100, 'max_depth': 15, 'learning_rate': 0.18043311207136256, 'reg_alpha': 0.18861495878553936, 'reg_lambda': 5.514725787121931e-06, 'subsample': 0.6390688456025535, 'colsample_bytree': 0.8736932106048627, 'min_child_weight': 7}. Best is trial 0 with value: 0.9481871858541476.
# [I 2025-10-27 20:18:40,155] Trial 5 finished with value: 0.9125831320041211 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.011085122517311707, 'reg_alpha': 1.527156759251193, 'reg_lambda': 2.133142332373004e-06, 'subsample': 0.8650089137415928, 'colsample_bytree': 0.7246844304357644, 'min_child_weight': 8}. Best is trial 0 with value: 0.9481871858541476.
# [I 2025-10-27 20:19:03,549] Trial 6 finished with value: 0.946881441567841 and parameters: {'n_estimators': 600, 'max_depth': 7, 'learning_rate': 0.18258230439200238, 'reg_alpha': 0.09466630153726856, 'reg_lambda': 2.854239907497756, 'subsample': 0.9579309401710595, 'colsample_bytree': 0.8391599915244341, 'min_child_weight': 14}. Best is trial 0 with value: 0.9481871858541476.
# [I 2025-10-27 20:19:19,224] Trial 7 finished with value: 0.8937508730974317 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.011450964268326641, 'reg_alpha': 8.471746987003668e-06, 'reg_lambda': 3.148441347423712e-05, 'subsample': 0.7085396127095583, 'colsample_bytree': 0.9314950036607718, 'min_child_weight': 6}. Best is trial 0 with value: 0.9481871858541476.
# [I 2025-10-27 20:21:08,747] Trial 8 finished with value: 0.9211554153317749 and parameters: {'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.015252697030515175, 'reg_alpha': 0.16587190283399655, 'reg_lambda': 4.6876566400928895e-08, 'subsample': 0.9947547746402069, 'colsample_bytree': 0.908897907718663, 'min_child_weight': 3}. Best is trial 0 with value: 0.9481871858541476.
# [I 2025-10-27 20:21:35,789] Trial 9 finished with value: 0.9375719506187407 and parameters: {'n_estimators': 100, 'max_depth': 13, 'learning_rate': 0.08310795711416077, 'reg_alpha': 0.03639690979811287, 'reg_lambda': 0.08738424135626986, 'subsample': 0.6296178606936361, 'colsample_bytree': 0.7433862914177091, 'min_child_weight': 2}. Best is trial 0 with value: 0.9481871858541476.
# [I 2025-10-27 20:22:00,407] Trial 10 finished with value: 0.952247603618518 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.07139614686948194, 'reg_alpha': 1.4509648127973841e-08, 'reg_lambda': 1.3750219655861316e-08, 'subsample': 0.775232370984732, 'colsample_bytree': 0.6060576948411027, 'min_child_weight': 14}. Best is trial 10 with value: 0.952247603618518.
# [I 2025-10-27 20:22:26,083] Trial 11 finished with value: 0.953016292338779 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.07780410191665421, 'reg_alpha': 1.427826218433985e-08, 'reg_lambda': 1.668583895056269e-08, 'subsample': 0.7737425087025646, 'colsample_bytree': 0.6068120358745437, 'min_child_weight': 14}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:22:55,192] Trial 12 finished with value: 0.9506754082298888 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.05772982138421647, 'reg_alpha': 1.0783672944450417e-08, 'reg_lambda': 2.5434051106140138e-08, 'subsample': 0.7881047401391955, 'colsample_bytree': 0.6138162997240784, 'min_child_weight': 11}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:23:40,160] Trial 13 finished with value: 0.9511444729917218 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.03246759239384837, 'reg_alpha': 1.2339064614047657e-08, 'reg_lambda': 4.872969385182971e-07, 'subsample': 0.7747702774708584, 'colsample_bytree': 0.9997449754566206, 'min_child_weight': 11}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:24:07,867] Trial 14 finished with value: 0.9471129075456771 and parameters: {'n_estimators': 800, 'max_depth': 7, 'learning_rate': 0.1091981450477759, 'reg_alpha': 2.727583689440576e-07, 'reg_lambda': 1.3129943022237607e-08, 'subsample': 0.8504707652071442, 'colsample_bytree': 0.6609387332293555, 'min_child_weight': 15}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:25:04,209] Trial 15 finished with value: 0.948922117784451 and parameters: {'n_estimators': 900, 'max_depth': 8, 'learning_rate': 0.053335174222032614, 'reg_alpha': 4.995109889922216e-07, 'reg_lambda': 0.00011774346598932867, 'subsample': 0.7539796407337818, 'colsample_bytree': 0.7696435002383372, 'min_child_weight': 11}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:25:20,290] Trial 16 finished with value: 0.9523510189775912 and parameters: {'n_estimators': 800, 'max_depth': 5, 'learning_rate': 0.12047535463777923, 'reg_alpha': 1.5299215074424424e-07, 'reg_lambda': 1.8804343456734505e-07, 'subsample': 0.8480246667851135, 'colsample_bytree': 0.6018960478612357, 'min_child_weight': 13}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:25:56,695] Trial 17 finished with value: 0.949174401532423 and parameters: {'n_estimators': 800, 'max_depth': 8, 'learning_rate': 0.12404066871939609, 'reg_alpha': 1.538039071236835e-05, 'reg_lambda': 4.861997212436086e-07, 'subsample': 0.859872185317448, 'colsample_bytree': 0.6693166700746467, 'min_child_weight': 12}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:26:18,372] Trial 18 finished with value: 0.9483545470397821 and parameters: {'n_estimators': 800, 'max_depth': 6, 'learning_rate': 0.13534838847131483, 'reg_alpha': 2.1225158471277842e-07, 'reg_lambda': 1.0780458313096994e-05, 'subsample': 0.9024069803384122, 'colsample_bytree': 0.6787733138751347, 'min_child_weight': 9}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:27:18,258] Trial 19 finished with value: 0.9452961317992261 and parameters: {'n_estimators': 700, 'max_depth': 8, 'learning_rate': 0.02722904223562264, 'reg_alpha': 7.847123733552038e-05, 'reg_lambda': 1.5273123986419755e-07, 'subsample': 0.73964158693172, 'colsample_bytree': 0.7763765924571042, 'min_child_weight': 15}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:28:00,529] Trial 20 finished with value: 0.9488597873064738 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.046458842052335705, 'reg_alpha': 1.2569054090325247e-07, 'reg_lambda': 0.001417654982862629, 'subsample': 0.826762339396572, 'colsample_bytree': 0.6403516919343936, 'min_child_weight': 9}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:28:25,482] Trial 21 finished with value: 0.9524359491556579 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.07153072600298362, 'reg_alpha': 3.969981262085678e-08, 'reg_lambda': 2.1095734379738764e-08, 'subsample': 0.8166276088335929, 'colsample_bytree': 0.6060084846502749, 'min_child_weight': 13}. Best is trial 11 with value: 0.953016292338779.
# [I 2025-10-27 20:29:01,943] Trial 22 finished with value: 0.953673174345633 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.07064297876170386, 'reg_alpha': 1.488338519810326e-06, 'reg_lambda': 1.2227176634565747e-06, 'subsample': 0.9171979198143885, 'colsample_bytree': 0.690690646696119, 'min_child_weight': 13}. Best is trial 22 with value: 0.953673174345633.
# [I 2025-10-27 20:29:34,889] Trial 23 finished with value: 0.9496889205097516 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.07264793515153606, 'reg_alpha': 2.0962561802959754e-06, 'reg_lambda': 1.880223089571001e-06, 'subsample': 0.8866494346501198, 'colsample_bytree': 0.6444727727979052, 'min_child_weight': 13}. Best is trial 22 with value: 0.953673174345633.
# [I 2025-10-27 20:30:33,243] Trial 24 finished with value: 0.9488522055650481 and parameters: {'n_estimators': 1000, 'max_depth': 9, 'learning_rate': 0.06848677952896201, 'reg_alpha': 5.3800744920673096e-08, 'reg_lambda': 4.323027807245537e-08, 'subsample': 0.9147695014171837, 'colsample_bytree': 0.706968547891932, 'min_child_weight': 10}. Best is trial 22 with value: 0.953673174345633.
# [I 2025-10-27 20:31:05,597] Trial 25 finished with value: 0.9496303037921378 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.09495880056200601, 'reg_alpha': 7.350691245697438e-07, 'reg_lambda': 8.293946651176253e-08, 'subsample': 0.8209637990480925, 'colsample_bytree': 0.6936203093319439, 'min_child_weight': 15}. Best is trial 22 with value: 0.953673174345633.
# [I 2025-10-27 20:31:32,459] Trial 26 finished with value: 0.9462256954817837 and parameters: {'n_estimators': 700, 'max_depth': 5, 'learning_rate': 0.04150379873559454, 'reg_alpha': 4.74631788096563e-08, 'reg_lambda': 1.4136107167645495e-06, 'subsample': 0.9515130356049577, 'colsample_bytree': 0.6584942569988029, 'min_child_weight': 12}. Best is trial 22 with value: 0.953673174345633.
# [I 2025-10-27 20:32:13,883] Trial 27 finished with value: 0.950958332143681 and parameters: {'n_estimators': 1000, 'max_depth': 7, 'learning_rate': 0.059477643233026706, 'reg_alpha': 3.3651633639099896e-05, 'reg_lambda': 1.0086543846760124e-08, 'subsample': 0.7291665208174549, 'colsample_bytree': 0.6331522648594204, 'min_child_weight': 14}. Best is trial 22 with value: 0.953673174345633.
# [I 2025-10-27 20:32:44,114] Trial 28 finished with value: 0.9491139064303824 and parameters: {'n_estimators': 900, 'max_depth': 9, 'learning_rate': 0.14934789469250442, 'reg_alpha': 1.663522851615274e-06, 'reg_lambda': 4.0194317513245176e-05, 'subsample': 0.8110353417686744, 'colsample_bytree': 0.6009917429679527, 'min_child_weight': 12}. Best is trial 22 with value: 0.953673174345633.
# [I 2025-10-27 20:33:10,057] Trial 29 finished with value: 0.946913031275985 and parameters: {'n_estimators': 600, 'max_depth': 6, 'learning_rate': 0.09455539085017425, 'reg_alpha': 0.0011269310521806871, 'reg_lambda': 4.4279552516566814e-07, 'subsample': 0.9409635051235963, 'colsample_bytree': 0.742581948272431, 'min_child_weight': 13}. Best is trial 22 with value: 0.953673174345633.
# [I 2025-10-27 20:35:00,659] Trial 30 finished with value: 0.950189487440483 and parameters: {'n_estimators': 1000, 'max_depth': 11, 'learning_rate': 0.024467165243154728, 'reg_alpha': 5.276660263860887e-08, 'reg_lambda': 1.005696057392375e-07, 'subsample': 0.7071548775773726, 'colsample_bytree': 0.6294557089850537, 'min_child_weight': 10}. Best is trial 22 with value: 0.953673174345633.
# [I 2025-10-27 20:35:16,332] Trial 31 finished with value: 0.9472059754340303 and parameters: {'n_estimators': 800, 'max_depth': 5, 'learning_rate': 0.11166180610452821, 'reg_alpha': 8.24779133497855e-07, 'reg_lambda': 2.1315489086354903e-07, 'subsample': 0.8403918518938343, 'colsample_bytree': 0.6204342283042433, 'min_child_weight': 13}. Best is trial 22 with value: 0.953673174345633.
# [I 2025-10-27 20:35:37,477] Trial 32 finished with value: 0.9539596065103585 and parameters: {'n_estimators': 900, 'max_depth': 5, 'learning_rate': 0.08499914348976342, 'reg_alpha': 8.581229931301884e-08, 'reg_lambda': 5.9557608538617e-08, 'subsample': 0.8868421704055203, 'colsample_bytree': 0.6016759765116763, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:36:10,975] Trial 33 finished with value: 0.9498492146051775 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.08652836349558432, 'reg_alpha': 4.363735472392193e-08, 'reg_lambda': 3.6293561974155476e-08, 'subsample': 0.8804970735646526, 'colsample_bytree': 0.6968617502800805, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:36:39,653] Trial 34 finished with value: 0.9486032153413899 and parameters: {'n_estimators': 900, 'max_depth': 5, 'learning_rate': 0.051267085379190155, 'reg_alpha': 0.00014429856197955277, 'reg_lambda': 1.2072276120898266e-06, 'subsample': 0.9302758765836151, 'colsample_bytree': 0.6489261708888365, 'min_child_weight': 15}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:37:06,864] Trial 35 finished with value: 0.9508062637510216 and parameters: {'n_estimators': 500, 'max_depth': 7, 'learning_rate': 0.06806719795605855, 'reg_alpha': 0.008689260794433502, 'reg_lambda': 0.031670226139725186, 'subsample': 0.8036133999263786, 'colsample_bytree': 0.6757878190648325, 'min_child_weight': 12}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:38:25,349] Trial 36 finished with value: 0.9505682557029527 and parameters: {'n_estimators': 700, 'max_depth': 14, 'learning_rate': 0.03778144509170327, 'reg_alpha': 3.7540154349141326e-06, 'reg_lambda': 7.831629639169259e-06, 'subsample': 0.9821507521534307, 'colsample_bytree': 0.6318562429417293, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:38:56,862] Trial 37 finished with value: 0.9516263359270217 and parameters: {'n_estimators': 1000, 'max_depth': 6, 'learning_rate': 0.08025348930696735, 'reg_alpha': 3.087475194205905e-08, 'reg_lambda': 7.437174719026668e-08, 'subsample': 0.8866783651897082, 'colsample_bytree': 0.7983951351316386, 'min_child_weight': 4}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:39:22,097] Trial 38 finished with value: 0.95028546571298 and parameters: {'n_estimators': 800, 'max_depth': 5, 'learning_rate': 0.05930611939659196, 'reg_alpha': 1.6488224187108332e-07, 'reg_lambda': 6.426578602422468e-07, 'subsample': 0.6010671845109126, 'colsample_bytree': 0.7342596173139949, 'min_child_weight': 13}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:39:46,957] Trial 39 finished with value: 0.9490530213719559 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.14983853015560167, 'reg_alpha': 1.0154951812778636e-05, 'reg_lambda': 6.5857833925072296, 'subsample': 0.9170352452651649, 'colsample_bytree': 0.6195635296501483, 'min_child_weight': 10}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:41:16,839] Trial 40 finished with value: 0.9536661917667674 and parameters: {'n_estimators': 700, 'max_depth': 12, 'learning_rate': 0.1019663374238256, 'reg_alpha': 5.271015091299249e-07, 'reg_lambda': 0.0006136102427832066, 'subsample': 0.9679837115578857, 'colsample_bytree': 0.6891148495518792, 'min_child_weight': 5}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:42:23,698] Trial 41 finished with value: 0.9487695793959676 and parameters: {'n_estimators': 700, 'max_depth': 12, 'learning_rate': 0.09593490731433459, 'reg_alpha': 4.59517439120463e-07, 'reg_lambda': 0.0012473833950010507, 'subsample': 0.9664045235568427, 'colsample_bytree': 0.8442177407612974, 'min_child_weight': 5}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:43:23,722] Trial 42 finished with value: 0.9492082094200295 and parameters: {'n_estimators': 600, 'max_depth': 12, 'learning_rate': 0.07874065851205729, 'reg_alpha': 9.02865328443984e-08, 'reg_lambda': 0.006849781385558407, 'subsample': 0.9792300444136454, 'colsample_bytree': 0.6892963056004586, 'min_child_weight': 6}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:44:16,901] Trial 43 finished with value: 0.9510686348303842 and parameters: {'n_estimators': 900, 'max_depth': 13, 'learning_rate': 0.10533527311031358, 'reg_alpha': 2.710355803655021e-08, 'reg_lambda': 0.0003656136318153236, 'subsample': 0.6710559300757173, 'colsample_bytree': 0.7148867216777486, 'min_child_weight': 7}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:47:55,421] Trial 45 finished with value: 0.9497519204518132 and parameters: {'n_estimators': 500, 'max_depth': 14, 'learning_rate': 0.1616387874121948, 'reg_alpha': 1.7292813191794945e-08, 'reg_lambda': 4.124074498860405e-06, 'subsample': 0.9988680684238408, 'colsample_bytree': 0.6568104352109381, 'min_child_weight': 2}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:48:35,400] Trial 46 finished with value: 0.9425755829651418 and parameters: {'n_estimators': 1000, 'max_depth': 11, 'learning_rate': 0.1948708897198102, 'reg_alpha': 1.5756047959843047, 'reg_lambda': 2.3649158819989028e-08, 'subsample': 0.7777358340316605, 'colsample_bytree': 0.8143462158665756, 'min_child_weight': 1}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:49:03,692] Trial 47 finished with value: 0.9516863977922286 and parameters: {'n_estimators': 800, 'max_depth': 5, 'learning_rate': 0.04864126712797791, 'reg_alpha': 8.845190824694795e-07, 'reg_lambda': 7.175473233388097e-05, 'subsample': 0.8685254564582843, 'colsample_bytree': 0.618700799185277, 'min_child_weight': 7}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:49:54,117] Trial 48 finished with value: 0.9479964306851794 and parameters: {'n_estimators': 900, 'max_depth': 9, 'learning_rate': 0.0857770841586437, 'reg_alpha': 1.1310717990882768e-08, 'reg_lambda': 2.2437328669197925e-05, 'subsample': 0.9065283709232613, 'colsample_bytree': 0.8927990853352347, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:50:18,432] Trial 49 finished with value: 0.944412778147076 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.07517700758391437, 'reg_alpha': 3.156707424845976e-07, 'reg_lambda': 0.007045794411652049, 'subsample': 0.9673306691323117, 'colsample_bytree': 0.9424596682742901, 'min_child_weight': 8}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:51:20,879] Trial 50 finished with value: 0.9498393232205449 and parameters: {'n_estimators': 1000, 'max_depth': 15, 'learning_rate': 0.1029387950294242, 'reg_alpha': 7.176144396845168e-06, 'reg_lambda': 1.9749586771193083e-08, 'subsample': 0.9430110996952035, 'colsample_bytree': 0.6002845359125436, 'min_child_weight': 11}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:51:37,486] Trial 51 finished with value: 0.9494669963080589 and parameters: {'n_estimators': 800, 'max_depth': 5, 'learning_rate': 0.12184407790849744, 'reg_alpha': 9.984837371101858e-08, 'reg_lambda': 1.6924276282028948e-07, 'subsample': 0.8457231329252084, 'colsample_bytree': 0.6081433023559585, 'min_child_weight': 13}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:51:52,625] Trial 52 finished with value: 0.9524069824888457 and parameters: {'n_estimators': 700, 'max_depth': 5, 'learning_rate': 0.12544982342843114, 'reg_alpha': 1.7852524307457447e-07, 'reg_lambda': 2.695469220104152e-07, 'subsample': 0.8323308570905149, 'colsample_bytree': 0.6397708248179844, 'min_child_weight': 12}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:52:10,336] Trial 53 finished with value: 0.9470194865296615 and parameters: {'n_estimators': 700, 'max_depth': 6, 'learning_rate': 0.12731709380326386, 'reg_alpha': 2.479785200872042e-07, 'reg_lambda': 5.344484793173446e-08, 'subsample': 0.794255927884921, 'colsample_bytree': 0.645225131701317, 'min_child_weight': 15}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:52:37,161] Trial 54 finished with value: 0.952808584493392 and parameters: {'n_estimators': 900, 'max_depth': 5, 'learning_rate': 0.06329331149114445, 'reg_alpha': 1.2657743455441287e-06, 'reg_lambda': 3.424865339309976e-07, 'subsample': 0.8222988512105661, 'colsample_bytree': 0.6725087128412601, 'min_child_weight': 12}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:53:15,870] Trial 55 finished with value: 0.948652572196506 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.05419907015310492, 'reg_alpha': 1.2802411026806948e-06, 'reg_lambda': 3.4065394852026623e-06, 'subsample': 0.7590055391421856, 'colsample_bytree': 0.6709473047591563, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:53:58,995] Trial 56 finished with value: 0.9511425134379373 and parameters: {'n_estimators': 1000, 'max_depth': 7, 'learning_rate': 0.06369312989385688, 'reg_alpha': 2.8722751314396355e-05, 'reg_lambda': 8.255489740018657e-07, 'subsample': 0.8135472870664548, 'colsample_bytree': 0.7194798035594302, 'min_child_weight': 11}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:54:24,868] Trial 57 finished with value: 0.9501447363227365 and parameters: {'n_estimators': 900, 'max_depth': 5, 'learning_rate': 0.07643686051115565, 'reg_alpha': 8.697573370973802e-08, 'reg_lambda': 1.1948867875056163e-08, 'subsample': 0.8618609386677247, 'colsample_bytree': 0.6875494105686921, 'min_child_weight': 13}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:55:10,352] Trial 58 finished with value: 0.9470884326291655 and parameters: {'n_estimators': 1000, 'max_depth': 6, 'learning_rate': 0.04214150142409167, 'reg_alpha': 4.5305034289992475e-06, 'reg_lambda': 2.8549743772328792e-08, 'subsample': 0.7843584589066013, 'colsample_bytree': 0.7070195298355, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:55:35,389] Trial 59 finished with value: 0.9487863741840914 and parameters: {'n_estimators': 800, 'max_depth': 5, 'learning_rate': 0.0642799921530974, 'reg_alpha': 2.0028804585668637e-08, 'reg_lambda': 0.0002284312339935402, 'subsample': 0.9005145504285994, 'colsample_bytree': 0.6613644348604653, 'min_child_weight': 12}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:56:23,647] Trial 60 finished with value: 0.9494109640660027 and parameters: {'n_estimators': 900, 'max_depth': 10, 'learning_rate': 0.08273578895831801, 'reg_alpha': 5.274310168461093e-07, 'reg_lambda': 1.0049187417841317e-07, 'subsample': 0.7622725752871977, 'colsample_bytree': 0.7323321650883274, 'min_child_weight': 15}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:56:41,748] Trial 61 finished with value: 0.9510717298411553 and parameters: {'n_estimators': 600, 'max_depth': 5, 'learning_rate': 0.09237499403766386, 'reg_alpha': 3.075855431399642e-07, 'reg_lambda': 3.331685601002426e-07, 'subsample': 0.8274080293594376, 'colsample_bytree': 0.6354117351846653, 'min_child_weight': 12}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:56:59,109] Trial 62 finished with value: 0.9520043692544718 and parameters: {'n_estimators': 700, 'max_depth': 5, 'learning_rate': 0.11089723094890756, 'reg_alpha': 1.209751474990586e-07, 'reg_lambda': 0.5565449845528222, 'subsample': 0.8285291780876088, 'colsample_bytree': 0.6144476119058907, 'min_child_weight': 11}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:57:21,280] Trial 63 finished with value: 0.9492512932802291 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.13813931132623056, 'reg_alpha': 6.29174988080637e-08, 'reg_lambda': 2.290754407331431e-07, 'subsample': 0.8747939602861409, 'colsample_bytree': 0.6421084880956629, 'min_child_weight': 12}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:57:59,981] Trial 64 finished with value: 0.9421967794603537 and parameters: {'n_estimators': 800, 'max_depth': 5, 'learning_rate': 0.01330304617644611, 'reg_alpha': 2.7502400859853078e-08, 'reg_lambda': 0.0008607961078697487, 'subsample': 0.8383649980112187, 'colsample_bytree': 0.6239221158483803, 'min_child_weight': 9}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:58:23,297] Trial 65 finished with value: 0.9493976116253712 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.07055360798026293, 'reg_alpha': 1.3403964432883654e-06, 'reg_lambda': 1.517073961817792e-05, 'subsample': 0.7460250458258441, 'colsample_bytree': 0.6544027648764562, 'min_child_weight': 13}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:58:46,052] Trial 66 finished with value: 0.9482668059554396 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.10011923997070936, 'reg_alpha': 4.267488633275009e-07, 'reg_lambda': 4.39452567509037e-08, 'subsample': 0.7980488426358773, 'colsample_bytree': 0.6782526731997589, 'min_child_weight': 13}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:59:14,587] Trial 67 finished with value: 0.9530782728572631 and parameters: {'n_estimators': 1000, 'max_depth': 7, 'learning_rate': 0.08957401814603069, 'reg_alpha': 1.0114357488901991e-08, 'reg_lambda': 1.2728883223938363e-07, 'subsample': 0.8952880811053002, 'colsample_bytree': 0.6653507930760241, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 20:59:58,908] Trial 68 finished with value: 0.9514402092624576 and parameters: {'n_estimators': 1000, 'max_depth': 7, 'learning_rate': 0.05522070470229898, 'reg_alpha': 2.4531936198373138e-08, 'reg_lambda': 9.872531495771605e-08, 'subsample': 0.894932630400293, 'colsample_bytree': 0.6993209925898892, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:00:25,640] Trial 69 finished with value: 0.9536748001449031 and parameters: {'n_estimators': 1000, 'max_depth': 6, 'learning_rate': 0.08924222246958632, 'reg_alpha': 1.1503625965358884e-08, 'reg_lambda': 9.273606989129645e-07, 'subsample': 0.7075423466381058, 'colsample_bytree': 0.6665403621149135, 'min_child_weight': 15}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:01:07,547] Trial 70 finished with value: 0.950303347551738 and parameters: {'n_estimators': 1000, 'max_depth': 8, 'learning_rate': 0.08992781184920756, 'reg_alpha': 1.1137887501060284e-08, 'reg_lambda': 7.495962019579888e-07, 'subsample': 0.7002044748202362, 'colsample_bytree': 0.6661462700901857, 'min_child_weight': 15}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:01:44,873] Trial 71 finished with value: 0.9498156492626114 and parameters: {'n_estimators': 1000, 'max_depth': 6, 'learning_rate': 0.07272551474777258, 'reg_alpha': 4.654524778310994e-08, 'reg_lambda': 1.941741110360179e-06, 'subsample': 0.7205293715293671, 'colsample_bytree': 0.682767683433281, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:02:13,910] Trial 72 finished with value: 0.946491385983587 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.08629171555155522, 'reg_alpha': 1.67348546228921e-08, 'reg_lambda': 6.124461399220986e-08, 'subsample': 0.9219967307570897, 'colsample_bytree': 0.6302107593692126, 'min_child_weight': 15}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:02:35,874] Trial 73 finished with value: 0.9511675857491273 and parameters: {'n_estimators': 1000, 'max_depth': 6, 'learning_rate': 0.1120882643253032, 'reg_alpha': 1.065782262275733e-08, 'reg_lambda': 2.1456078432030907e-08, 'subsample': 0.9399850551910252, 'colsample_bytree': 0.6118885789854714, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:03:02,220] Trial 74 finished with value: 0.9519224614452821 and parameters: {'n_estimators': 900, 'max_depth': 5, 'learning_rate': 0.0614364084079587, 'reg_alpha': 5.484956175158314e-08, 'reg_lambda': 4.757841812876292e-07, 'subsample': 0.6483813507591079, 'colsample_bytree': 0.6512121382432773, 'min_child_weight': 13}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:03:42,780] Trial 75 finished with value: 0.9488882382361099 and parameters: {'n_estimators': 1000, 'max_depth': 7, 'learning_rate': 0.06835086574070538, 'reg_alpha': 0.0006277044915012413, 'reg_lambda': 1.4635659141331925e-07, 'subsample': 0.8570653182241335, 'colsample_bytree': 0.7032568148131086, 'min_child_weight': 15}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:04:06,058] Trial 76 finished with value: 0.9514211475799925 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.08242459603289991, 'reg_alpha': 3.234867978416478e-08, 'reg_lambda': 2.837061090584628e-06, 'subsample': 0.680730331200602, 'colsample_bytree': 0.6696967440385286, 'min_child_weight': 4}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:04:54,029] Trial 77 finished with value: 0.9480051637838829 and parameters: {'n_estimators': 1000, 'max_depth': 7, 'learning_rate': 0.0499993994436956, 'reg_alpha': 1.5360674138474028e-07, 'reg_lambda': 1.3242729283112258e-06, 'subsample': 0.9595126629031163, 'colsample_bytree': 0.7539042974627544, 'min_child_weight': 14}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:05:52,331] Trial 78 finished with value: 0.9502741357583199 and parameters: {'n_estimators': 900, 'max_depth': 12, 'learning_rate': 0.09727930967305431, 'reg_alpha': 8.955885280921223e-08, 'reg_lambda': 5.941980028011639e-06, 'subsample': 0.8899324924509971, 'colsample_bytree': 0.6246314111607765, 'min_child_weight': 13}. Best is trial 32 with value: 0.9539596065103585.
# [I 2025-10-27 21:06:21,286] Trial 79 finished with value: 0.9545469158244413 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.07803569978156424, 'reg_alpha': 0.007442335317936633, 'reg_lambda': 1.692192495215684e-08, 'subsample': 0.9091422465787298, 'colsample_bytree': 0.7838213008581549, 'min_child_weight': 15}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:07:15,703] Trial 80 finished with value: 0.9482137285022747 and parameters: {'n_estimators': 1000, 'max_depth': 10, 'learning_rate': 0.07826176906069561, 'reg_alpha': 0.0159567487300738, 'reg_lambda': 0.0030930402323272226, 'subsample': 0.9079444195623683, 'colsample_bytree': 0.7861842772887846, 'min_child_weight': 15}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:07:50,238] Trial 81 finished with value: 0.9505972582313158 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.05728149509752988, 'reg_alpha': 0.015603793516607744, 'reg_lambda': 1.5800424354221686e-08, 'subsample': 0.8811420487722093, 'colsample_bytree': 0.8168517159939201, 'min_child_weight': 14}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:09:00,228] Trial 82 finished with value: 0.9497552291493349 and parameters: {'n_estimators': 1000, 'max_depth': 14, 'learning_rate': 0.09062686269273265, 'reg_alpha': 0.0019802304898125216, 'reg_lambda': 3.6376663347340045e-08, 'subsample': 0.9327794151791168, 'colsample_bytree': 0.8532245686296656, 'min_child_weight': 15}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:09:27,826] Trial 83 finished with value: 0.9503689385117754 and parameters: {'n_estimators': 900, 'max_depth': 5, 'learning_rate': 0.06618860160953027, 'reg_alpha': 0.11548929890043602, 'reg_lambda': 1.2111472561799978e-07, 'subsample': 0.9825202153587084, 'colsample_bytree': 0.7123426236921198, 'min_child_weight': 14}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:10:04,579] Trial 84 finished with value: 0.9532164640105533 and parameters: {'n_estimators': 1000, 'max_depth': 6, 'learning_rate': 0.07498025188366002, 'reg_alpha': 0.00024463259592213195, 'reg_lambda': 6.48450719981634e-08, 'subsample': 0.8129045036223013, 'colsample_bytree': 0.6099488279732055, 'min_child_weight': 15}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:10:37,009] Trial 85 finished with value: 0.9481554133265353 and parameters: {'n_estimators': 1000, 'max_depth': 6, 'learning_rate': 0.10308740297347277, 'reg_alpha': 0.00016993877025291655, 'reg_lambda': 2.9148311462640964e-07, 'subsample': 0.807840858604925, 'colsample_bytree': 0.7264896297221104, 'min_child_weight': 15}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:11:16,129] Trial 86 finished with value: 0.9480727008811134 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.07538044373852393, 'reg_alpha': 1.3107558214089041, 'reg_lambda': 1.0097708193671612e-08, 'subsample': 0.9139441699320221, 'colsample_bytree': 0.6930017167127196, 'min_child_weight': 15}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:11:41,904] Trial 87 finished with value: 0.9485736208299398 and parameters: {'n_estimators': 800, 'max_depth': 7, 'learning_rate': 0.11700633029279746, 'reg_alpha': 4.872321156376323e-05, 'reg_lambda': 0.0006368115274159376, 'subsample': 0.9516137527397927, 'colsample_bytree': 0.9583601183187173, 'min_child_weight': 14}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:12:33,751] Trial 88 finished with value: 0.9503144995289262 and parameters: {'n_estimators': 1000, 'max_depth': 13, 'learning_rate': 0.08173230918466688, 'reg_alpha': 0.006644037411995008, 'reg_lambda': 6.38863765910845e-08, 'subsample': 0.7663991382213312, 'colsample_bytree': 0.6831649514022475, 'min_child_weight': 15}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:12:43,507] Trial 89 finished with value: 0.940657022830836 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.04525987149295938, 'reg_alpha': 0.00028569070012326975, 'reg_lambda': 0.00013879670078026515, 'subsample': 0.8527211471985758, 'colsample_bytree': 0.6098849874133125, 'min_child_weight': 14}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:13:53,035] Trial 90 finished with value: 0.9403813782623733 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.01000219948899336, 'reg_alpha': 0.3944007593565401, 'reg_lambda': 3.708897377376476e-08, 'subsample': 0.8735707674546757, 'colsample_bytree': 0.6478420134556595, 'min_child_weight': 13}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:14:18,544] Trial 91 finished with value: 0.9527741697076372 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.07165760205247002, 'reg_alpha': 1.6550101654713746e-05, 'reg_lambda': 2.2264689732565214e-08, 'subsample': 0.8179160819255665, 'colsample_bytree': 0.6017957505365809, 'min_child_weight': 13}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:14:42,594] Trial 92 finished with value: 0.952718495595386 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.07189172215247346, 'reg_alpha': 1.3821235262894019e-05, 'reg_lambda': 2.562394035517576e-08, 'subsample': 0.8194144631253029, 'colsample_bytree': 0.6199401479630866, 'min_child_weight': 14}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:15:04,109] Trial 93 finished with value: 0.9539185963578317 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.08835708258982654, 'reg_alpha': 2.6641435331489333e-06, 'reg_lambda': 7.523282722956561e-08, 'subsample': 0.7799760254167257, 'colsample_bytree': 0.6014652595040635, 'min_child_weight': 13}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:15:31,559] Trial 94 finished with value: 0.9527689052182411 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.08895972449932221, 'reg_alpha': 2.935143604592332e-06, 'reg_lambda': 1.5171770228730673e-07, 'subsample': 0.7289850346542527, 'colsample_bytree': 0.6363465963434694, 'min_child_weight': 15}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:15:57,387] Trial 95 finished with value: 0.9520295684440234 and parameters: {'n_estimators': 900, 'max_depth': 6, 'learning_rate': 0.09657719143913572, 'reg_alpha': 5.556174591330798e-06, 'reg_lambda': 7.603764207667737e-08, 'subsample': 0.7816505315140104, 'colsample_bytree': 0.6622731898885683, 'min_child_weight': 14}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:16:23,307] Trial 96 finished with value: 0.9521049648622112 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.07805176840947418, 'reg_alpha': 8.822966905959666e-07, 'reg_lambda': 3.5887473966101283e-07, 'subsample': 0.7944681421178724, 'colsample_bytree': 0.6254425629713642, 'min_child_weight': 15}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:16:51,595] Trial 97 finished with value: 0.9540647682794605 and parameters: {'n_estimators': 800, 'max_depth': 6, 'learning_rate': 0.10680139230257256, 'reg_alpha': 0.0375185148096245, 'reg_lambda': 7.700274471655915e-07, 'subsample': 0.7712534108891996, 'colsample_bytree': 0.6000013580956983, 'min_child_weight': 13}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:17:18,939] Trial 98 finished with value: 0.9467359290525885 and parameters: {'n_estimators': 800, 'max_depth': 7, 'learning_rate': 0.1305634877153461, 'reg_alpha': 0.0037217937331325977, 'reg_lambda': 6.471736045669286e-07, 'subsample': 0.7709949290643098, 'colsample_bytree': 0.6087042456185334, 'min_child_weight': 2}. Best is trial 79 with value: 0.9545469158244413.
# [I 2025-10-27 21:17:58,798] Trial 99 finished with value: 0.9484881532356793 and parameters: {'n_estimators': 800, 'max_depth': 8, 'learning_rate': 0.1073115321933048, 'reg_alpha': 0.05469795890112863, 'reg_lambda': 1.5680762977088818e-08, 'subsample': 0.7337304796562207, 'colsample_bytree': 0.615365346728464, 'min_child_weight': 5}. Best is trial 79 with value: 0.9545469158244413.
# Optuna HPO complete in 3981.72 seconds.
#
# Best Hyperparameters Found (Optuna):
#   max_depth: 5
#   learning_rate: 0.07803569978156424
#   reg_alpha: 0.007442335317936633
#   reg_lambda: 1.692192495215684e-08
#   subsample: 0.9091422465787298
#   colsample_bytree: 0.7838213008581549
#   min_child_weight: 15
#   n_estimators (Best): 1000
# Final Model trained on (Train + Val) in 29.0861 seconds.
#
# ================================================================================
# COMPLETE HPO PERFORMANCE REPORT (Swin-base Hybrid + XGBoost)
# ================================================================================
# Training Accuracy              0.999894
# Training Precision             0.999893
# Training Recall                0.999889
# Training F1 Score              0.999891
# Training Loss                  0.005128
# Training TPR                   0.999889
# Training FPR                   0.000013
# Training Time (s)              101.4761
# Validation Accuracy            1.000000
# Validation Precision           1.000000
# Validation Recall              1.000000
# Validation F1 Score            1.000000
# Validation Loss                0.004308
# Validation TPR                 1.000000
# Validation FPR                 0.000000
# Validation Time (s)            10.4933
# Testing Accuracy               0.943739
# Testing Precision              0.943610
# Testing Recall                 0.942432
# Testing F1 Score               0.942948
# Testing Loss                   0.162134
# Testing TPR                    0.942432
# Testing FPR                    0.007042
# Testing AUROC                  0.997637
# Testing Time (s)               8.9028
#
# ------------------------------ TESTING CLASSIFICATION REPORT ------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       235
#            1       0.96      0.97      0.97       301
#            2       0.91      0.92      0.91       286
#            3       0.95      0.94      0.95       252
#            4       0.96      0.94      0.95       196
#            5       0.95      0.96      0.95       258
#            6       0.98      0.99      0.98       299
#            7       0.92      0.93      0.92       270
#            8       0.95      0.92      0.93       267
#
#     accuracy                           0.94      2364
#    macro avg       0.94      0.94      0.94      2364
# weighted avg       0.94      0.94      0.94      2364
